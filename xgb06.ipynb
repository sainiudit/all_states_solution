# %%
import numpy as np
import pandas as pd
import xgboost as xgb

from datetime import datetime
from sklearn.metrics import mean_absolute_error
from sklearn.cross_validation import KFold
from scipy.stats import skew, boxcox
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import itertools
import os
os.chdir("/home/udit/ipython/notebook/all/input")

shift = 200
COMB_FEATURE = 'cat80,cat87,cat57,cat12,cat79,cat10,cat7,cat89,cat2,cat72,' \
               'cat81,cat11,cat1,cat13,cat9,cat3,cat16,cat90,cat23,cat36,' \
               'cat73,cat103,cat40,cat28,cat111,cat6,cat76,cat50,cat5,' \
               'cat4,cat14,cat38,cat24,cat82,cat25'.split(',')

def encode(charcode):
    r = 0
    ln = len(str(charcode))
    for i in range(ln):
        r += (ord(str(charcode)[i]) - ord('A') + 1) * 26 ** (ln - i - 1)
    return r

fair_constant = 0.7
def fair_obj(preds, dtrain):
    labels = dtrain.get_label()
    x = (preds - labels)
    den = abs(x) + fair_constant
    grad = fair_constant * x / (den)
    hess = fair_constant * fair_constant / (den * den)
    return grad, hess

def xg_eval_mae(yhat, dtrain):
    y = dtrain.get_label()
    return 'mae', mean_absolute_error(np.exp(y)-shift,
                                      np.exp(yhat)-shift)
def mungeskewed(train, test, numeric_feats):
    ntrain = train.shape[0]
    test['loss'] = 0
    train_test = pd.concat((train, test)).reset_index(drop=True)
    skewed_feats = train[numeric_feats].apply(lambda x: skew(x.dropna()))
    skewed_feats = skewed_feats[skewed_feats > 0.25]
    skewed_feats = skewed_feats.index

    for feats in skewed_feats:
        train_test[feats] = train_test[feats] + 1
        train_test[feats], lam = boxcox(train_test[feats])
    return train_test, ntrain
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
directory = '../input/'
train = pd.read_csv(directory + 'train.csv')
test = pd.read_csv(directory + 'test.csv')

numeric_feats = [x for x in train.columns[1:-1] if 'cont' in x]
categorical_feats = [x for x in train.columns[1:-1] if 'cat' in x]
train_test, ntrain = mungeskewed(train, test, numeric_feats)

# taken from Vladimir's script (https://www.kaggle.com/iglovikov/allstate-claims-severity/xgb-1114)
for column in list(train.select_dtypes(include=['object']).columns):
    if train[column].nunique() != test[column].nunique():
        set_train = set(train[column].unique())
        set_test = set(test[column].unique())
        remove_train = set_train - set_test
        remove_test = set_test - set_train

        remove = remove_train.union(remove_test)


        def filter_cat(x):
            if x in remove:
                return np.nan
            return x


        train_test[column] = train_test[column].apply(lambda x: filter_cat(x), 1)

# taken from Ali's script (https://www.kaggle.com/aliajouz/allstate-claims-severity/singel-model-lb-1117)
train_test["cont1"] = np.sqrt(preprocessing.minmax_scale(train_test["cont1"]))
train_test["cont4"] = np.sqrt(preprocessing.minmax_scale(train_test["cont4"]))
train_test["cont5"] = np.sqrt(preprocessing.minmax_scale(train_test["cont5"]))
train_test["cont8"] = np.sqrt(preprocessing.minmax_scale(train_test["cont8"]))
train_test["cont10"] = np.sqrt(preprocessing.minmax_scale(train_test["cont10"]))
train_test["cont11"] = np.sqrt(preprocessing.minmax_scale(train_test["cont11"]))
train_test["cont12"] = np.sqrt(preprocessing.minmax_scale(train_test["cont12"]))

train_test["cont6"] = np.log(preprocessing.minmax_scale(train_test["cont6"]) + 0000.1)
train_test["cont7"] = np.log(preprocessing.minmax_scale(train_test["cont7"]) + 0000.1)
train_test["cont9"] = np.log(preprocessing.minmax_scale(train_test["cont9"]) + 0000.1)
train_test["cont13"] = np.log(preprocessing.minmax_scale(train_test["cont13"]) + 0000.1)
train_test["cont14"] = (np.maximum(train_test["cont14"] - 0.179722, 0) / 0.665122) ** 0.25

print('')
for comb in itertools.combinations(COMB_FEATURE, 2):
    feat = comb[0] + "_" + comb[1]
    train_test[feat] = train_test[comb[0]] + train_test[comb[1]]
    train_test[feat] = train_test[feat].apply(encode)
    print('Combining Columns:', feat)

print('')
for col in categorical_feats:
    print('Analyzing Column:', col)
    train_test[col] = train_test[col].apply(encode)

print(train_test[categorical_feats])

ss = StandardScaler()
train_test[numeric_feats] = \
    ss.fit_transform(train_test[numeric_feats].values)

train = train_test.iloc[:ntrain, :].copy()
test = train_test.iloc[ntrain:, :].copy()

print('\nMedian Loss:', train.loss.median())
print('Mean Loss:', train.loss.mean())

ids = pd.read_csv('../input/test.csv')['id']
train_y = np.log(train['loss'] + shift)
train_x = train.drop(['loss','id'], axis=1)
test_x = test.drop(['loss','id'], axis=1)
# Out:
# ('Combining Columns:', 'cat80_cat87')
# ('Combining Columns:', 'cat80_cat57')
# ('Combining Columns:', 'cat80_cat12')
# ('Combining Columns:', 'cat80_cat79')
# ('Combining Columns:', 'cat80_cat10')
# ('Combining Columns:', 'cat80_cat7')
# ('Combining Columns:', 'cat80_cat89')
# ('Combining Columns:', 'cat80_cat2')
# ('Combining Columns:', 'cat80_cat72')
# ('Combining Columns:', 'cat80_cat81')
# ('Combining Columns:', 'cat80_cat11')
# ('Combining Columns:', 'cat80_cat1')
# ('Combining Columns:', 'cat80_cat13')
# ('Combining Columns:', 'cat80_cat9')
# ('Combining Columns:', 'cat80_cat3')
# ('Combining Columns:', 'cat80_cat16')
# ('Combining Columns:', 'cat80_cat90')
# ('Combining Columns:', 'cat80_cat23')
# ('Combining Columns:', 'cat80_cat36')
# ('Combining Columns:', 'cat80_cat73')
# ('Combining Columns:', 'cat80_cat103')
# ('Combining Columns:', 'cat80_cat40')
# ('Combining Columns:', 'cat80_cat28')
# ('Combining Columns:', 'cat80_cat111')
# ('Combining Columns:', 'cat80_cat6')
# ('Combining Columns:', 'cat80_cat76')
# ('Combining Columns:', 'cat80_cat50')
# ('Combining Columns:', 'cat80_cat5')
# ('Combining Columns:', 'cat80_cat4')
# ('Combining Columns:', 'cat80_cat14')
# ('Combining Columns:', 'cat80_cat38')
# ('Combining Columns:', 'cat80_cat24')
# ('Combining Columns:', 'cat80_cat82')
# ('Combining Columns:', 'cat80_cat25')
# ('Combining Columns:', 'cat87_cat57')
# ('Combining Columns:', 'cat87_cat12')
# ('Combining Columns:', 'cat87_cat79')
# ('Combining Columns:', 'cat87_cat10')
# ('Combining Columns:', 'cat87_cat7')
# ('Combining Columns:', 'cat87_cat89')
# ('Combining Columns:', 'cat87_cat2')
# ('Combining Columns:', 'cat87_cat72')
# ('Combining Columns:', 'cat87_cat81')
# ('Combining Columns:', 'cat87_cat11')
# ('Combining Columns:', 'cat87_cat1')
# ('Combining Columns:', 'cat87_cat13')
# ('Combining Columns:', 'cat87_cat9')
# ('Combining Columns:', 'cat87_cat3')
# ('Combining Columns:', 'cat87_cat16')
# ('Combining Columns:', 'cat87_cat90')
# ('Combining Columns:', 'cat87_cat23')
# ('Combining Columns:', 'cat87_cat36')
# ('Combining Columns:', 'cat87_cat73')
# ('Combining Columns:', 'cat87_cat103')
# ('Combining Columns:', 'cat87_cat40')
# ('Combining Columns:', 'cat87_cat28')
# ('Combining Columns:', 'cat87_cat111')
# ('Combining Columns:', 'cat87_cat6')
# ('Combining Columns:', 'cat87_cat76')
# ('Combining Columns:', 'cat87_cat50')
# ('Combining Columns:', 'cat87_cat5')
# ('Combining Columns:', 'cat87_cat4')
# ('Combining Columns:', 'cat87_cat14')
# ('Combining Columns:', 'cat87_cat38')
# ('Combining Columns:', 'cat87_cat24')
# ('Combining Columns:', 'cat87_cat82')
# ('Combining Columns:', 'cat87_cat25')
# ('Combining Columns:', 'cat57_cat12')
# ('Combining Columns:', 'cat57_cat79')
# ('Combining Columns:', 'cat57_cat10')
# ('Combining Columns:', 'cat57_cat7')
# ('Combining Columns:', 'cat57_cat89')
# ('Combining Columns:', 'cat57_cat2')
# ('Combining Columns:', 'cat57_cat72')
# ('Combining Columns:', 'cat57_cat81')
# ('Combining Columns:', 'cat57_cat11')
# ('Combining Columns:', 'cat57_cat1')
# ('Combining Columns:', 'cat57_cat13')
# ('Combining Columns:', 'cat57_cat9')
# ('Combining Columns:', 'cat57_cat3')
# ('Combining Columns:', 'cat57_cat16')
# ('Combining Columns:', 'cat57_cat90')
# ('Combining Columns:', 'cat57_cat23')
# ('Combining Columns:', 'cat57_cat36')
# ('Combining Columns:', 'cat57_cat73')
# ('Combining Columns:', 'cat57_cat103')
# ('Combining Columns:', 'cat57_cat40')
# ('Combining Columns:', 'cat57_cat28')
# ('Combining Columns:', 'cat57_cat111')
# ('Combining Columns:', 'cat57_cat6')
# ('Combining Columns:', 'cat57_cat76')
# ('Combining Columns:', 'cat57_cat50')
# ('Combining Columns:', 'cat57_cat5')
# ('Combining Columns:', 'cat57_cat4')
# ('Combining Columns:', 'cat57_cat14')
# ('Combining Columns:', 'cat57_cat38')
# ('Combining Columns:', 'cat57_cat24')
# ('Combining Columns:', 'cat57_cat82')
# ('Combining Columns:', 'cat57_cat25')
# ('Combining Columns:', 'cat12_cat79')
# ('Combining Columns:', 'cat12_cat10')
# ('Combining Columns:', 'cat12_cat7')
# ('Combining Columns:', 'cat12_cat89')
# ('Combining Columns:', 'cat12_cat2')
# ('Combining Columns:', 'cat12_cat72')
# ('Combining Columns:', 'cat12_cat81')
# ('Combining Columns:', 'cat12_cat11')
# ('Combining Columns:', 'cat12_cat1')
# ('Combining Columns:', 'cat12_cat13')
# ('Combining Columns:', 'cat12_cat9')
# ('Combining Columns:', 'cat12_cat3')
# ('Combining Columns:', 'cat12_cat16')
# ('Combining Columns:', 'cat12_cat90')
# ('Combining Columns:', 'cat12_cat23')
# ('Combining Columns:', 'cat12_cat36')
# ('Combining Columns:', 'cat12_cat73')
# ('Combining Columns:', 'cat12_cat103')
# ('Combining Columns:', 'cat12_cat40')
# ('Combining Columns:', 'cat12_cat28')
# ('Combining Columns:', 'cat12_cat111')
# ('Combining Columns:', 'cat12_cat6')
# ('Combining Columns:', 'cat12_cat76')
# ('Combining Columns:', 'cat12_cat50')
# ('Combining Columns:', 'cat12_cat5')
# ('Combining Columns:', 'cat12_cat4')
# ('Combining Columns:', 'cat12_cat14')
# ('Combining Columns:', 'cat12_cat38')
# ('Combining Columns:', 'cat12_cat24')
# ('Combining Columns:', 'cat12_cat82')
# ('Combining Columns:', 'cat12_cat25')
# ('Combining Columns:', 'cat79_cat10')
# ('Combining Columns:', 'cat79_cat7')
# ('Combining Columns:', 'cat79_cat89')
# ('Combining Columns:', 'cat79_cat2')
# ('Combining Columns:', 'cat79_cat72')
# ('Combining Columns:', 'cat79_cat81')
# ('Combining Columns:', 'cat79_cat11')
# ('Combining Columns:', 'cat79_cat1')
# ('Combining Columns:', 'cat79_cat13')
# ('Combining Columns:', 'cat79_cat9')
# ('Combining Columns:', 'cat79_cat3')
# ('Combining Columns:', 'cat79_cat16')
# ('Combining Columns:', 'cat79_cat90')
# ('Combining Columns:', 'cat79_cat23')
# ('Combining Columns:', 'cat79_cat36')
# ('Combining Columns:', 'cat79_cat73')
# ('Combining Columns:', 'cat79_cat103')
# ('Combining Columns:', 'cat79_cat40')
# ('Combining Columns:', 'cat79_cat28')
# ('Combining Columns:', 'cat79_cat111')
# ('Combining Columns:', 'cat79_cat6')
# ('Combining Columns:', 'cat79_cat76')
# ('Combining Columns:', 'cat79_cat50')
# ('Combining Columns:', 'cat79_cat5')
# ('Combining Columns:', 'cat79_cat4')
# ('Combining Columns:', 'cat79_cat14')
# ('Combining Columns:', 'cat79_cat38')
# ('Combining Columns:', 'cat79_cat24')
# ('Combining Columns:', 'cat79_cat82')
# ('Combining Columns:', 'cat79_cat25')
# ('Combining Columns:', 'cat10_cat7')
# ('Combining Columns:', 'cat10_cat89')
# ('Combining Columns:', 'cat10_cat2')
# ('Combining Columns:', 'cat10_cat72')
# ('Combining Columns:', 'cat10_cat81')
# ('Combining Columns:', 'cat10_cat11')
# ('Combining Columns:', 'cat10_cat1')
# ('Combining Columns:', 'cat10_cat13')
# ('Combining Columns:', 'cat10_cat9')
# ('Combining Columns:', 'cat10_cat3')
# ('Combining Columns:', 'cat10_cat16')
# ('Combining Columns:', 'cat10_cat90')
# ('Combining Columns:', 'cat10_cat23')
# ('Combining Columns:', 'cat10_cat36')
# ('Combining Columns:', 'cat10_cat73')
# ('Combining Columns:', 'cat10_cat103')
# ('Combining Columns:', 'cat10_cat40')
# ('Combining Columns:', 'cat10_cat28')
# ('Combining Columns:', 'cat10_cat111')
# ('Combining Columns:', 'cat10_cat6')
# ('Combining Columns:', 'cat10_cat76')
# ('Combining Columns:', 'cat10_cat50')
# ('Combining Columns:', 'cat10_cat5')
# ('Combining Columns:', 'cat10_cat4')
# ('Combining Columns:', 'cat10_cat14')
# ('Combining Columns:', 'cat10_cat38')
# ('Combining Columns:', 'cat10_cat24')
# ('Combining Columns:', 'cat10_cat82')
# ('Combining Columns:', 'cat10_cat25')
# ('Combining Columns:', 'cat7_cat89')
# ('Combining Columns:', 'cat7_cat2')
# ('Combining Columns:', 'cat7_cat72')
# ('Combining Columns:', 'cat7_cat81')
# ('Combining Columns:', 'cat7_cat11')
# ('Combining Columns:', 'cat7_cat1')
# ('Combining Columns:', 'cat7_cat13')
# ('Combining Columns:', 'cat7_cat9')
# ('Combining Columns:', 'cat7_cat3')
# ('Combining Columns:', 'cat7_cat16')
# ('Combining Columns:', 'cat7_cat90')
# ('Combining Columns:', 'cat7_cat23')
# ('Combining Columns:', 'cat7_cat36')
# ('Combining Columns:', 'cat7_cat73')
# ('Combining Columns:', 'cat7_cat103')
# ('Combining Columns:', 'cat7_cat40')
# ('Combining Columns:', 'cat7_cat28')
# ('Combining Columns:', 'cat7_cat111')
# ('Combining Columns:', 'cat7_cat6')
# ('Combining Columns:', 'cat7_cat76')
# ('Combining Columns:', 'cat7_cat50')
# ('Combining Columns:', 'cat7_cat5')
# ('Combining Columns:', 'cat7_cat4')
# ('Combining Columns:', 'cat7_cat14')
# ('Combining Columns:', 'cat7_cat38')
# ('Combining Columns:', 'cat7_cat24')
# ('Combining Columns:', 'cat7_cat82')
# ('Combining Columns:', 'cat7_cat25')
# ('Combining Columns:', 'cat89_cat2')
# ('Combining Columns:', 'cat89_cat72')
# ('Combining Columns:', 'cat89_cat81')
# ('Combining Columns:', 'cat89_cat11')
# ('Combining Columns:', 'cat89_cat1')
# ('Combining Columns:', 'cat89_cat13')
# ('Combining Columns:', 'cat89_cat9')
# ('Combining Columns:', 'cat89_cat3')
# ('Combining Columns:', 'cat89_cat16')
# ('Combining Columns:', 'cat89_cat90')
# ('Combining Columns:', 'cat89_cat23')
# ('Combining Columns:', 'cat89_cat36')
# ('Combining Columns:', 'cat89_cat73')
# ('Combining Columns:', 'cat89_cat103')
# ('Combining Columns:', 'cat89_cat40')
# ('Combining Columns:', 'cat89_cat28')
# ('Combining Columns:', 'cat89_cat111')
# ('Combining Columns:', 'cat89_cat6')
# ('Combining Columns:', 'cat89_cat76')
# ('Combining Columns:', 'cat89_cat50')
# ('Combining Columns:', 'cat89_cat5')
# ('Combining Columns:', 'cat89_cat4')
# ('Combining Columns:', 'cat89_cat14')
# ('Combining Columns:', 'cat89_cat38')
# ('Combining Columns:', 'cat89_cat24')
# ('Combining Columns:', 'cat89_cat82')
# ('Combining Columns:', 'cat89_cat25')
# ('Combining Columns:', 'cat2_cat72')
# ('Combining Columns:', 'cat2_cat81')
# ('Combining Columns:', 'cat2_cat11')
# ('Combining Columns:', 'cat2_cat1')
# ('Combining Columns:', 'cat2_cat13')
# ('Combining Columns:', 'cat2_cat9')
# ('Combining Columns:', 'cat2_cat3')
# ('Combining Columns:', 'cat2_cat16')
# ('Combining Columns:', 'cat2_cat90')
# ('Combining Columns:', 'cat2_cat23')
# ('Combining Columns:', 'cat2_cat36')
# ('Combining Columns:', 'cat2_cat73')
# ('Combining Columns:', 'cat2_cat103')
# ('Combining Columns:', 'cat2_cat40')
# ('Combining Columns:', 'cat2_cat28')
# ('Combining Columns:', 'cat2_cat111')
# ('Combining Columns:', 'cat2_cat6')
# ('Combining Columns:', 'cat2_cat76')
# ('Combining Columns:', 'cat2_cat50')
# ('Combining Columns:', 'cat2_cat5')
# ('Combining Columns:', 'cat2_cat4')
# ('Combining Columns:', 'cat2_cat14')
# ('Combining Columns:', 'cat2_cat38')
# ('Combining Columns:', 'cat2_cat24')
# ('Combining Columns:', 'cat2_cat82')
# ('Combining Columns:', 'cat2_cat25')
# ('Combining Columns:', 'cat72_cat81')
# ('Combining Columns:', 'cat72_cat11')
# ('Combining Columns:', 'cat72_cat1')
# ('Combining Columns:', 'cat72_cat13')
# ('Combining Columns:', 'cat72_cat9')
# ('Combining Columns:', 'cat72_cat3')
# ('Combining Columns:', 'cat72_cat16')
# ('Combining Columns:', 'cat72_cat90')
# ('Combining Columns:', 'cat72_cat23')
# ('Combining Columns:', 'cat72_cat36')
# ('Combining Columns:', 'cat72_cat73')
# ('Combining Columns:', 'cat72_cat103')
# ('Combining Columns:', 'cat72_cat40')
# ('Combining Columns:', 'cat72_cat28')
# ('Combining Columns:', 'cat72_cat111')
# ('Combining Columns:', 'cat72_cat6')
# ('Combining Columns:', 'cat72_cat76')
# ('Combining Columns:', 'cat72_cat50')
# ('Combining Columns:', 'cat72_cat5')
# ('Combining Columns:', 'cat72_cat4')
# ('Combining Columns:', 'cat72_cat14')
# ('Combining Columns:', 'cat72_cat38')
# ('Combining Columns:', 'cat72_cat24')
# ('Combining Columns:', 'cat72_cat82')
# ('Combining Columns:', 'cat72_cat25')
# ('Combining Columns:', 'cat81_cat11')
# ('Combining Columns:', 'cat81_cat1')
# ('Combining Columns:', 'cat81_cat13')
# ('Combining Columns:', 'cat81_cat9')
# ('Combining Columns:', 'cat81_cat3')
# ('Combining Columns:', 'cat81_cat16')
# ('Combining Columns:', 'cat81_cat90')
# ('Combining Columns:', 'cat81_cat23')
# ('Combining Columns:', 'cat81_cat36')
# ('Combining Columns:', 'cat81_cat73')
# ('Combining Columns:', 'cat81_cat103')
# ('Combining Columns:', 'cat81_cat40')
# ('Combining Columns:', 'cat81_cat28')
# ('Combining Columns:', 'cat81_cat111')
# ('Combining Columns:', 'cat81_cat6')
# ('Combining Columns:', 'cat81_cat76')
# ('Combining Columns:', 'cat81_cat50')
# ('Combining Columns:', 'cat81_cat5')
# ('Combining Columns:', 'cat81_cat4')
# ('Combining Columns:', 'cat81_cat14')
# ('Combining Columns:', 'cat81_cat38')
# ('Combining Columns:', 'cat81_cat24')
# ('Combining Columns:', 'cat81_cat82')
# ('Combining Columns:', 'cat81_cat25')
# ('Combining Columns:', 'cat11_cat1')
# ('Combining Columns:', 'cat11_cat13')
# ('Combining Columns:', 'cat11_cat9')
# ('Combining Columns:', 'cat11_cat3')
# ('Combining Columns:', 'cat11_cat16')
# ('Combining Columns:', 'cat11_cat90')
# ('Combining Columns:', 'cat11_cat23')
# ('Combining Columns:', 'cat11_cat36')
# ('Combining Columns:', 'cat11_cat73')
# ('Combining Columns:', 'cat11_cat103')
# ('Combining Columns:', 'cat11_cat40')
# ('Combining Columns:', 'cat11_cat28')
# ('Combining Columns:', 'cat11_cat111')
# ('Combining Columns:', 'cat11_cat6')
# ('Combining Columns:', 'cat11_cat76')
# ('Combining Columns:', 'cat11_cat50')
# ('Combining Columns:', 'cat11_cat5')
# ('Combining Columns:', 'cat11_cat4')
# ('Combining Columns:', 'cat11_cat14')
# ('Combining Columns:', 'cat11_cat38')
# ('Combining Columns:', 'cat11_cat24')
# ('Combining Columns:', 'cat11_cat82')
# ('Combining Columns:', 'cat11_cat25')
# ('Combining Columns:', 'cat1_cat13')
# ('Combining Columns:', 'cat1_cat9')
# ('Combining Columns:', 'cat1_cat3')
# ('Combining Columns:', 'cat1_cat16')
# ('Combining Columns:', 'cat1_cat90')
# ('Combining Columns:', 'cat1_cat23')
# ('Combining Columns:', 'cat1_cat36')
# ('Combining Columns:', 'cat1_cat73')
# ('Combining Columns:', 'cat1_cat103')
# ('Combining Columns:', 'cat1_cat40')
# ('Combining Columns:', 'cat1_cat28')
# ('Combining Columns:', 'cat1_cat111')
# ('Combining Columns:', 'cat1_cat6')
# ('Combining Columns:', 'cat1_cat76')
# ('Combining Columns:', 'cat1_cat50')
# ('Combining Columns:', 'cat1_cat5')
# ('Combining Columns:', 'cat1_cat4')
# ('Combining Columns:', 'cat1_cat14')
# ('Combining Columns:', 'cat1_cat38')
# ('Combining Columns:', 'cat1_cat24')
# ('Combining Columns:', 'cat1_cat82')
# ('Combining Columns:', 'cat1_cat25')
# ('Combining Columns:', 'cat13_cat9')
# ('Combining Columns:', 'cat13_cat3')
# ('Combining Columns:', 'cat13_cat16')
# ('Combining Columns:', 'cat13_cat90')
# ('Combining Columns:', 'cat13_cat23')
# ('Combining Columns:', 'cat13_cat36')
# ('Combining Columns:', 'cat13_cat73')
# ('Combining Columns:', 'cat13_cat103')
# ('Combining Columns:', 'cat13_cat40')
# ('Combining Columns:', 'cat13_cat28')
# ('Combining Columns:', 'cat13_cat111')
# ('Combining Columns:', 'cat13_cat6')
# ('Combining Columns:', 'cat13_cat76')
# ('Combining Columns:', 'cat13_cat50')
# ('Combining Columns:', 'cat13_cat5')
# ('Combining Columns:', 'cat13_cat4')
# ('Combining Columns:', 'cat13_cat14')
# ('Combining Columns:', 'cat13_cat38')
# ('Combining Columns:', 'cat13_cat24')
# ('Combining Columns:', 'cat13_cat82')
# ('Combining Columns:', 'cat13_cat25')
# ('Combining Columns:', 'cat9_cat3')
# ('Combining Columns:', 'cat9_cat16')
# ('Combining Columns:', 'cat9_cat90')
# ('Combining Columns:', 'cat9_cat23')
# ('Combining Columns:', 'cat9_cat36')
# ('Combining Columns:', 'cat9_cat73')
# ('Combining Columns:', 'cat9_cat103')
# ('Combining Columns:', 'cat9_cat40')
# ('Combining Columns:', 'cat9_cat28')
# ('Combining Columns:', 'cat9_cat111')
# ('Combining Columns:', 'cat9_cat6')
# ('Combining Columns:', 'cat9_cat76')
# ('Combining Columns:', 'cat9_cat50')
# ('Combining Columns:', 'cat9_cat5')
# ('Combining Columns:', 'cat9_cat4')
# ('Combining Columns:', 'cat9_cat14')
# ('Combining Columns:', 'cat9_cat38')
# ('Combining Columns:', 'cat9_cat24')
# ('Combining Columns:', 'cat9_cat82')
# ('Combining Columns:', 'cat9_cat25')
# ('Combining Columns:', 'cat3_cat16')
# ('Combining Columns:', 'cat3_cat90')
# ('Combining Columns:', 'cat3_cat23')
# ('Combining Columns:', 'cat3_cat36')
# ('Combining Columns:', 'cat3_cat73')
# ('Combining Columns:', 'cat3_cat103')
# ('Combining Columns:', 'cat3_cat40')
# ('Combining Columns:', 'cat3_cat28')
# ('Combining Columns:', 'cat3_cat111')
# ('Combining Columns:', 'cat3_cat6')
# ('Combining Columns:', 'cat3_cat76')
# ('Combining Columns:', 'cat3_cat50')
# ('Combining Columns:', 'cat3_cat5')
# ('Combining Columns:', 'cat3_cat4')
# ('Combining Columns:', 'cat3_cat14')
# ('Combining Columns:', 'cat3_cat38')
# ('Combining Columns:', 'cat3_cat24')
# ('Combining Columns:', 'cat3_cat82')
# ('Combining Columns:', 'cat3_cat25')
# ('Combining Columns:', 'cat16_cat90')
# ('Combining Columns:', 'cat16_cat23')
# ('Combining Columns:', 'cat16_cat36')
# ('Combining Columns:', 'cat16_cat73')
# ('Combining Columns:', 'cat16_cat103')
# ('Combining Columns:', 'cat16_cat40')
# ('Combining Columns:', 'cat16_cat28')
# ('Combining Columns:', 'cat16_cat111')
# ('Combining Columns:', 'cat16_cat6')
# ('Combining Columns:', 'cat16_cat76')
# ('Combining Columns:', 'cat16_cat50')
# ('Combining Columns:', 'cat16_cat5')
# ('Combining Columns:', 'cat16_cat4')
# ('Combining Columns:', 'cat16_cat14')
# ('Combining Columns:', 'cat16_cat38')
# ('Combining Columns:', 'cat16_cat24')
# ('Combining Columns:', 'cat16_cat82')
# ('Combining Columns:', 'cat16_cat25')
# ('Combining Columns:', 'cat90_cat23')
# ('Combining Columns:', 'cat90_cat36')
# ('Combining Columns:', 'cat90_cat73')
# ('Combining Columns:', 'cat90_cat103')
# ('Combining Columns:', 'cat90_cat40')
# ('Combining Columns:', 'cat90_cat28')
# ('Combining Columns:', 'cat90_cat111')
# ('Combining Columns:', 'cat90_cat6')
# ('Combining Columns:', 'cat90_cat76')
# ('Combining Columns:', 'cat90_cat50')
# ('Combining Columns:', 'cat90_cat5')
# ('Combining Columns:', 'cat90_cat4')
# ('Combining Columns:', 'cat90_cat14')
# ('Combining Columns:', 'cat90_cat38')
# ('Combining Columns:', 'cat90_cat24')
# ('Combining Columns:', 'cat90_cat82')
# ('Combining Columns:', 'cat90_cat25')
# ('Combining Columns:', 'cat23_cat36')
# ('Combining Columns:', 'cat23_cat73')
# ('Combining Columns:', 'cat23_cat103')
# ('Combining Columns:', 'cat23_cat40')
# ('Combining Columns:', 'cat23_cat28')
# ('Combining Columns:', 'cat23_cat111')
# ('Combining Columns:', 'cat23_cat6')
# ('Combining Columns:', 'cat23_cat76')
# ('Combining Columns:', 'cat23_cat50')
# ('Combining Columns:', 'cat23_cat5')
# ('Combining Columns:', 'cat23_cat4')
# ('Combining Columns:', 'cat23_cat14')
# ('Combining Columns:', 'cat23_cat38')
# ('Combining Columns:', 'cat23_cat24')
# ('Combining Columns:', 'cat23_cat82')
# ('Combining Columns:', 'cat23_cat25')
# ('Combining Columns:', 'cat36_cat73')
# ('Combining Columns:', 'cat36_cat103')
# ('Combining Columns:', 'cat36_cat40')
# ('Combining Columns:', 'cat36_cat28')
# ('Combining Columns:', 'cat36_cat111')
# ('Combining Columns:', 'cat36_cat6')
# ('Combining Columns:', 'cat36_cat76')
# ('Combining Columns:', 'cat36_cat50')
# ('Combining Columns:', 'cat36_cat5')
# ('Combining Columns:', 'cat36_cat4')
# ('Combining Columns:', 'cat36_cat14')
# ('Combining Columns:', 'cat36_cat38')
# ('Combining Columns:', 'cat36_cat24')
# ('Combining Columns:', 'cat36_cat82')
# ('Combining Columns:', 'cat36_cat25')
# ('Combining Columns:', 'cat73_cat103')
# ('Combining Columns:', 'cat73_cat40')
# ('Combining Columns:', 'cat73_cat28')
# ('Combining Columns:', 'cat73_cat111')
# ('Combining Columns:', 'cat73_cat6')
# ('Combining Columns:', 'cat73_cat76')
# ('Combining Columns:', 'cat73_cat50')
# ('Combining Columns:', 'cat73_cat5')
# ('Combining Columns:', 'cat73_cat4')
# ('Combining Columns:', 'cat73_cat14')
# ('Combining Columns:', 'cat73_cat38')
# ('Combining Columns:', 'cat73_cat24')
# ('Combining Columns:', 'cat73_cat82')
# ('Combining Columns:', 'cat73_cat25')
# ('Combining Columns:', 'cat103_cat40')
# ('Combining Columns:', 'cat103_cat28')
# ('Combining Columns:', 'cat103_cat111')
# ('Combining Columns:', 'cat103_cat6')
# ('Combining Columns:', 'cat103_cat76')
# ('Combining Columns:', 'cat103_cat50')
# ('Combining Columns:', 'cat103_cat5')
# ('Combining Columns:', 'cat103_cat4')
# ('Combining Columns:', 'cat103_cat14')
# ('Combining Columns:', 'cat103_cat38')
# ('Combining Columns:', 'cat103_cat24')
# ('Combining Columns:', 'cat103_cat82')
# ('Combining Columns:', 'cat103_cat25')
# ('Combining Columns:', 'cat40_cat28')
# ('Combining Columns:', 'cat40_cat111')
# ('Combining Columns:', 'cat40_cat6')
# ('Combining Columns:', 'cat40_cat76')
# ('Combining Columns:', 'cat40_cat50')
# ('Combining Columns:', 'cat40_cat5')
# ('Combining Columns:', 'cat40_cat4')
# ('Combining Columns:', 'cat40_cat14')
# ('Combining Columns:', 'cat40_cat38')
# ('Combining Columns:', 'cat40_cat24')
# ('Combining Columns:', 'cat40_cat82')
# ('Combining Columns:', 'cat40_cat25')
# ('Combining Columns:', 'cat28_cat111')
# ('Combining Columns:', 'cat28_cat6')
# ('Combining Columns:', 'cat28_cat76')
# ('Combining Columns:', 'cat28_cat50')
# ('Combining Columns:', 'cat28_cat5')
# ('Combining Columns:', 'cat28_cat4')
# ('Combining Columns:', 'cat28_cat14')
# ('Combining Columns:', 'cat28_cat38')
# ('Combining Columns:', 'cat28_cat24')
# ('Combining Columns:', 'cat28_cat82')
# ('Combining Columns:', 'cat28_cat25')
# ('Combining Columns:', 'cat111_cat6')
# ('Combining Columns:', 'cat111_cat76')
# ('Combining Columns:', 'cat111_cat50')
# ('Combining Columns:', 'cat111_cat5')
# ('Combining Columns:', 'cat111_cat4')
# ('Combining Columns:', 'cat111_cat14')
# ('Combining Columns:', 'cat111_cat38')
# ('Combining Columns:', 'cat111_cat24')
# ('Combining Columns:', 'cat111_cat82')
# ('Combining Columns:', 'cat111_cat25')
# ('Combining Columns:', 'cat6_cat76')
# ('Combining Columns:', 'cat6_cat50')
# ('Combining Columns:', 'cat6_cat5')
# ('Combining Columns:', 'cat6_cat4')
# ('Combining Columns:', 'cat6_cat14')
# ('Combining Columns:', 'cat6_cat38')
# ('Combining Columns:', 'cat6_cat24')
# ('Combining Columns:', 'cat6_cat82')
# ('Combining Columns:', 'cat6_cat25')
# ('Combining Columns:', 'cat76_cat50')
# ('Combining Columns:', 'cat76_cat5')
# ('Combining Columns:', 'cat76_cat4')
# ('Combining Columns:', 'cat76_cat14')
# ('Combining Columns:', 'cat76_cat38')
# ('Combining Columns:', 'cat76_cat24')
# ('Combining Columns:', 'cat76_cat82')
# ('Combining Columns:', 'cat76_cat25')
# ('Combining Columns:', 'cat50_cat5')
# ('Combining Columns:', 'cat50_cat4')
# ('Combining Columns:', 'cat50_cat14')
# ('Combining Columns:', 'cat50_cat38')
# ('Combining Columns:', 'cat50_cat24')
# ('Combining Columns:', 'cat50_cat82')
# ('Combining Columns:', 'cat50_cat25')
# ('Combining Columns:', 'cat5_cat4')
# ('Combining Columns:', 'cat5_cat14')
# ('Combining Columns:', 'cat5_cat38')
# ('Combining Columns:', 'cat5_cat24')
# ('Combining Columns:', 'cat5_cat82')
# ('Combining Columns:', 'cat5_cat25')
# ('Combining Columns:', 'cat4_cat14')
# ('Combining Columns:', 'cat4_cat38')
# ('Combining Columns:', 'cat4_cat24')
# ('Combining Columns:', 'cat4_cat82')
# ('Combining Columns:', 'cat4_cat25')
# ('Combining Columns:', 'cat14_cat38')
# ('Combining Columns:', 'cat14_cat24')
# ('Combining Columns:', 'cat14_cat82')
# ('Combining Columns:', 'cat14_cat25')
# ('Combining Columns:', 'cat38_cat24')
# ('Combining Columns:', 'cat38_cat82')
# ('Combining Columns:', 'cat38_cat25')
# ('Combining Columns:', 'cat24_cat82')
# ('Combining Columns:', 'cat24_cat25')
# ('Combining Columns:', 'cat82_cat25')
#
# ('Analyzing Column:', 'cat1')
# ('Analyzing Column:', 'cat2')
# ('Analyzing Column:', 'cat3')
# ('Analyzing Column:', 'cat4')
# ('Analyzing Column:', 'cat5')
# ('Analyzing Column:', 'cat6')
# ('Analyzing Column:', 'cat7')
# ('Analyzing Column:', 'cat8')
# ('Analyzing Column:', 'cat9')
# ('Analyzing Column:', 'cat10')
# ('Analyzing Column:', 'cat11')
# ('Analyzing Column:', 'cat12')
# ('Analyzing Column:', 'cat13')
# ('Analyzing Column:', 'cat14')
# ('Analyzing Column:', 'cat15')
# ('Analyzing Column:', 'cat16')
# ('Analyzing Column:', 'cat17')
# ('Analyzing Column:', 'cat18')
# ('Analyzing Column:', 'cat19')
# ('Analyzing Column:', 'cat20')
# ('Analyzing Column:', 'cat21')
# ('Analyzing Column:', 'cat22')
# ('Analyzing Column:', 'cat23')
# ('Analyzing Column:', 'cat24')
# ('Analyzing Column:', 'cat25')
# ('Analyzing Column:', 'cat26')
# ('Analyzing Column:', 'cat27')
# ('Analyzing Column:', 'cat28')
# ('Analyzing Column:', 'cat29')
# ('Analyzing Column:', 'cat30')
# ('Analyzing Column:', 'cat31')
# ('Analyzing Column:', 'cat32')
# ('Analyzing Column:', 'cat33')
# ('Analyzing Column:', 'cat34')
# ('Analyzing Column:', 'cat35')
# ('Analyzing Column:', 'cat36')
# ('Analyzing Column:', 'cat37')
# ('Analyzing Column:', 'cat38')
# ('Analyzing Column:', 'cat39')
# ('Analyzing Column:', 'cat40')
# ('Analyzing Column:', 'cat41')
# ('Analyzing Column:', 'cat42')
# ('Analyzing Column:', 'cat43')
# ('Analyzing Column:', 'cat44')
# ('Analyzing Column:', 'cat45')
# ('Analyzing Column:', 'cat46')
# ('Analyzing Column:', 'cat47')
# ('Analyzing Column:', 'cat48')
# ('Analyzing Column:', 'cat49')
# ('Analyzing Column:', 'cat50')
# ('Analyzing Column:', 'cat51')
# ('Analyzing Column:', 'cat52')
# ('Analyzing Column:', 'cat53')
# ('Analyzing Column:', 'cat54')
# ('Analyzing Column:', 'cat55')
# ('Analyzing Column:', 'cat56')
# ('Analyzing Column:', 'cat57')
# ('Analyzing Column:', 'cat58')
# ('Analyzing Column:', 'cat59')
# ('Analyzing Column:', 'cat60')
# ('Analyzing Column:', 'cat61')
# ('Analyzing Column:', 'cat62')
# ('Analyzing Column:', 'cat63')
# ('Analyzing Column:', 'cat64')
# ('Analyzing Column:', 'cat65')
# ('Analyzing Column:', 'cat66')
# ('Analyzing Column:', 'cat67')
# ('Analyzing Column:', 'cat68')
# ('Analyzing Column:', 'cat69')
# ('Analyzing Column:', 'cat70')
# ('Analyzing Column:', 'cat71')
# ('Analyzing Column:', 'cat72')
# ('Analyzing Column:', 'cat73')
# ('Analyzing Column:', 'cat74')
# ('Analyzing Column:', 'cat75')
# ('Analyzing Column:', 'cat76')
# ('Analyzing Column:', 'cat77')
# ('Analyzing Column:', 'cat78')
# ('Analyzing Column:', 'cat79')
# ('Analyzing Column:', 'cat80')
# ('Analyzing Column:', 'cat81')
# ('Analyzing Column:', 'cat82')
# ('Analyzing Column:', 'cat83')
# ('Analyzing Column:', 'cat84')
# ('Analyzing Column:', 'cat85')
# ('Analyzing Column:', 'cat86')
# ('Analyzing Column:', 'cat87')
# ('Analyzing Column:', 'cat88')
# ('Analyzing Column:', 'cat89')
# ('Analyzing Column:', 'cat90')
# ('Analyzing Column:', 'cat91')
# ('Analyzing Column:', 'cat92')
# ('Analyzing Column:', 'cat93')
# ('Analyzing Column:', 'cat94')
# ('Analyzing Column:', 'cat95')
# ('Analyzing Column:', 'cat96')
# ('Analyzing Column:', 'cat97')
# ('Analyzing Column:', 'cat98')
# ('Analyzing Column:', 'cat99')
# ('Analyzing Column:', 'cat100')
# ('Analyzing Column:', 'cat101')
# ('Analyzing Column:', 'cat102')
# ('Analyzing Column:', 'cat103')
# ('Analyzing Column:', 'cat104')
# ('Analyzing Column:', 'cat105')
# ('Analyzing Column:', 'cat106')
# ('Analyzing Column:', 'cat107')
# ('Analyzing Column:', 'cat108')
# ('Analyzing Column:', 'cat109')
# ('Analyzing Column:', 'cat110')
# ('Analyzing Column:', 'cat111')
# ('Analyzing Column:', 'cat112')
# ('Analyzing Column:', 'cat113')
# ('Analyzing Column:', 'cat114')
# ('Analyzing Column:', 'cat115')
# ('Analyzing Column:', 'cat116')
#         cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  cat10   ...    \
# 0          1     2     1     2     1     1     1     1     2      1   ...
# 1          1     2     1     1     1     1     1     1     2      2   ...
# 2          1     2     1     1     2     1     1     1     2      2   ...
# 3          2     2     1     2     1     1     1     1     2      1   ...
# 4          1     2     1     2     1     1     1     1     2      2   ...
# 5          1     2     1     1     1     1     1     1     2      1   ...
# 6          1     1     1     1     2     1     1     1     1      1   ...
# 7          1     2     1     2     1     1     1     1     2      1   ...
# 8          1     2     2     2     2     1     1     1     2      2   ...
# 9          1     2     1     1     2     2     1     1     2      1   ...
# 10         1     2     1     1     1     1     1     1     2      2   ...
# 11         1     2     1     1     2     1     1     1     2      2   ...
# 12         2     1     1     1     2     1     1     1     1      1   ...
# 13         2     1     1     1     2     2     1     1     1      1   ...
# 14         1     1     1     1     2     1     1     1     1      1   ...
# 15         1     1     1     1     2     2     1     1     1      1   ...
# 16         1     2     2     1     1     1     1     1     2      2   ...
# 17         1     1     1     1     1     2     1     1     1      1   ...
# 18         1     1     2     1     1     2     1     1     1      1   ...
# 19         1     1     1     2     1     1     1     1     1      1   ...
# 20         2     2     1     2     1     1     1     1     2      1   ...
# 21         1     1     1     2     1     2     1     1     1      1   ...
# 22         2     1     1     1     2     2     1     1     1      1   ...
# 23         2     1     1     2     1     1     1     1     1      1   ...
# 24         2     1     1     1     1     1     1     1     1      1   ...
# 25         1     1     1     2     1     1     1     1     1      1   ...
# 26         1     1     1     1     1     2     1     1     1      1   ...
# 27         2     1     1     2     1     1     1     1     1      1   ...
# 28         1     2     1     2     1     2     1     1     2      1   ...
# 29         1     1     1     1     2     1     1     1     1      1   ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 313834     1     2     1     1     1     1     1     2     2      1   ...
# 313835     1     2     1     2     2     1     1     1     2      2   ...
# 313836     1     2     1     1     2     1     1     1     2      1   ...
# 313837     2     1     1     1     1     2     1     1     1      1   ...
# 313838     2     2     1     1     1     1     1     1     2      2   ...
# 313839     1     1     1     1     1     2     1     1     1      1   ...
# 313840     1     1     1     1     1     2     1     1     1      1   ...
# 313841     1     2     1     1     1     2     1     1     2      1   ...
# 313842     1     1     1     1     1     2     1     1     1      1   ...
# 313843     1     1     1     1     2     1     1     1     1      1   ...
# 313844     1     1     1     1     1     2     1     1     1      1   ...
# 313845     1     1     1     2     2     1     1     1     1      1   ...
# 313846     1     1     1     1     1     2     1     1     1      1   ...
# 313847     1     1     2     1     1     1     1     1     1      1   ...
# 313848     1     2     1     1     2     1     1     1     2      1   ...
# 313849     1     2     1     1     1     1     1     1     2      1   ...
# 313850     1     1     1     2     2     1     2     1     1      1   ...
# 313851     1     1     1     2     1     1     1     1     1      1   ...
# 313852     1     2     1     1     2     1     1     1     2      1   ...
# 313853     2     1     1     1     2     2     1     1     1      1   ...
# 313854     2     1     1     1     2     1     1     1     1      1   ...
# 313855     1     1     1     2     1     1     1     1     1      1   ...
# 313856     1     2     1     1     2     1     1     1     2      1   ...
# 313857     1     1     1     2     1     1     1     1     1      1   ...
# 313858     1     1     2     1     1     2     1     1     1      1   ...
# 313859     1     1     1     2     1     1     1     1     1      1   ...
# 313860     1     1     1     1     2     2     1     2     1      1   ...
# 313861     2     2     1     1     2     1     1     1     2      2   ...
# 313862     1     1     1     1     1     2     1     2     1      1   ...
# 313863     1     2     1     1     1     1     1     1     2      1   ...
#
#         cat107  cat108  cat109  cat110  cat111  cat112  cat113  cat114  \
# 0           10       7      73      55       3      45      19       1
# 1           11      11      61      95       1      48      65       1
# 2            6       1      28     115       1       3      32       1
# 3           11      11      61      97       3      14      31       1
# 4            7       2       8       3       3      25      65       1
# 5            6       2      61      97       1      45      31       1
# 6            6       2      61     115       1      10      32       1
# 7            9       7      61     132       7      34      25       1
# 8           13      11      61      55       3      11      50       1
# 9           10       7      73     127       1      21      19      10
# 10           6       4      61      39       1      45       8       1
# 11           6       2      61      35       1       5      50       1
# 12          11      11      61      97       1       5      31       1
# 13           7       1      28     137       1      37      11       5
# 14           8       7      61     137       1      34      12       1
# 15           8      11      61      95       1      35      65       3
# 16           6       2      61      90       1      31       1       1
# 17           7       7      73      55       1       1      19       6
# 18           6       4      61      97       1      48      10       6
# 19          11      11      61      71       5      12      65       1
# 20          11      11      61      97       3       6      31       1
# 21          12      11      61      35       3      42      25       5
# 22          11       9      61     132       1      45      31       6
# 23           6       2      61      97       9      30      65       1
# 24           6       1      61      72       1      32      32       1
# 25           6       2      61     132       5      48      37       1
# 26           7       4      61     137       1      38       8       5
# 27           6       2      61      97       5       5      65       1
# 28           9       6      61     132       7      40      31       3
# 29          10       6      28     132       1      21      14       1
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 313834      11      11      61     132       1      45      31       1
# 313835      12       3      61     127       3      14      25       1
# 313836       7       2      18     142       1      34      37       1
# 313837      11      11      83       3       1      45      63      10
# 313838       6       2      61      72       1      48      50       1
# 313839       9       6      61     132       1      42      31       5
# 313840       6       4      61      90       1       5      46       3
# 313841       7       4      61      90       1       5      40       5
# 313842       9       6      61     127       1      49      19       3
# 313843       8       2      13      93       1      10      50       1
# 313844       6       2      61      97       1      34      31      12
# 313845      10      11      28     137       5      45      12       1
# 313846      11      11      61      72       1      27      50       6
# 313847       6       4      61      88       1      45      41       1
# 313848      11      11      11     132       1       5      31       1
# 313849       6       2      61      90       1      45       9       1
# 313850       9      11      61      90       7      34      30       1
# 313851       5       4      61     137      11       9       8       1
# 313852      10      11      61      68       1       3      65       1
# 313853       7       4      61      23       1       3      33       5
# 313854       5       4      61      29       1       5       8       1
# 313855       9       6      61      72       7      14      50       1
# 313856       8       4      61     142       1      10       8       1
# 313857      10       1      11     142       5      39      32       1
# 313858       7       2      61      90       1      39      62       3
# 313859       6       4      61      90       3      35       8       1
# 313860      10      11      61     117       1      48      62      10
# 313861       8       7      61      68       1       5      65       1
# 313862      11      11      11     132       1      11      31       5
# 313863       7       2      28     142       1      32      32       1
#
#         cat115  cat116
# 0           15     314
# 1           15     120
# 2            9     193
# 3           15     114
# 4           11      89
# 5           11     114
# 6           11     114
# 7           16     327
# 8           17     239
# 9           15     337
# 10          11     201
# 11          11     219
# 12          15     114
# 13          11     107
# 14          16     354
# 15          12     123
# 16          10     114
# 17          15     317
# 18          11     225
# 19          18     218
# 20          15     114
# 21          16     185
# 22          14      77
# 23          11     120
# 24           9     232
# 25          11     220
# 26          11     201
# 27          11     114
# 28          14     219
# 29          13     215
# ...        ...     ...
# 313834      14     219
# 313835      18     309
# 313836      11     115
# 313837      16     193
# 313838      11     120
# 313839      14     219
# 313840      10     222
# 313841      10     191
# 313842      13     215
# 313843      12      96
# 313844      11     114
# 313845      15     218
# 313846      17     336
# 313847      10     219
# 313848      15     114
# 313849      11     225
# 313850      14     225
# 313851      10     318
# 313852      15     201
# 313853      12     219
# 313854      10     318
# 313855      15     219
# 313856      11     201
# 313857      13      80
# 313858      12     120
# 313859      11     201
# 313860      15     120
# 313861      16     337
# 313862      15     114
# 313863      12      96
#
# [313864 rows x 116 columns]
# ('\nMedian Loss:', 2115.5699999999997)
# ('Mean Loss:', 3037.3376856699833)

# %%
d_train_full = xgb.DMatrix(train_x, label=train_y)
d_test = xgb.DMatrix(test_x)

# %%
n_folds = 30
cv_sum = 0
early_stopping = 100
fpred = []
xgb_rounds = []
import pickle
kf = KFold(train.shape[0], n_folds=n_folds)
for i, (train_index, test_index) in enumerate(kf):
    print('\n Fold %d' % (i+1))
    X_train, X_val = train_x.iloc[train_index], train_x.iloc[test_index]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[test_index]

    rand_state = 2016

    params = {
        'seed': 0,
        'colsample_bytree': 0.7,
        'silent': 1,
        'subsample': 0.7,
        'learning_rate': 0.03,
        'objective': 'reg:linear',
        'max_depth': 12,
        'min_child_weight': 100,
        'booster': 'gbtree'}

    d_train = xgb.DMatrix(X_train, label=y_train)
    d_valid = xgb.DMatrix(X_val, label=y_val)
    watchlist = [(d_train, 'train'), (d_valid, 'eval')]

    clf = xgb.train(params,
                    d_train,
                    10000,
                    watchlist,
                    early_stopping_rounds=50,
                    obj=fair_obj,
                    feval=xg_eval_mae)

    xgb_rounds.append(clf.best_iteration)
    scores_val = clf.predict(d_valid, ntree_limit=clf.best_ntree_limit)
    cv_score = mean_absolute_error(np.exp(y_val), np.exp(scores_val))
    pickle.dump(clf, open("models/model_fold"+str(i+1)+"score_"+str(cv_score)+"best_round"+str(clf.best_ntree_limit)+".dat", "wb"))
    print('eval-MAE: %.6f' % cv_score)
    y_pred = np.exp(clf.predict(d_test, ntree_limit=clf.best_ntree_limit)) - shift

    if i > 0:
        fpred = pred + y_pred
    else:
        fpred = y_pred
    pred = fpred
    cv_sum = cv_sum + cv_score
# Out:
#  Fold 1
# [0]	train-mae:3216.4	eval-mae:3245.51
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 50 rounds.
# [1]	train-mae:3174.51	eval-mae:3203.73
# [2]	train-mae:3113.69	eval-mae:3142.79
# [3]	train-mae:3040.35	eval-mae:3069.31
# [4]	train-mae:2960.31	eval-mae:2988.98
# [5]	train-mae:2877.64	eval-mae:2905.82
# [6]	train-mae:2794.87	eval-mae:2822.72
# [7]	train-mae:2714.22	eval-mae:2741.89
# [8]	train-mae:2635.82	eval-mae:2663.03
# [9]	train-mae:2560.69	eval-mae:2587.48
# [10]	train-mae:2488.18	eval-mae:2514.51
# [11]	train-mae:2419.81	eval-mae:2445.99
# [12]	train-mae:2354.37	eval-mae:2379.93
# [13]	train-mae:2292.4	eval-mae:2317.77
# [14]	train-mae:2234.04	eval-mae:2259.3
# [15]	train-mae:2178.17	eval-mae:2203.33
# [16]	train-mae:2125.45	eval-mae:2150.58
# [17]	train-mae:2075.74	eval-mae:2100.95
# [18]	train-mae:2028.54	eval-mae:2053.45
# [19]	train-mae:1983.89	eval-mae:2008.41
# [20]	train-mae:1941.39	eval-mae:1965.5
# [21]	train-mae:1901.16	eval-mae:1924.99
# [22]	train-mae:1862.59	eval-mae:1886.5
# [23]	train-mae:1826.1	eval-mae:1850.09
# [24]	train-mae:1791.33	eval-mae:1815.4
# [25]	train-mae:1758.47	eval-mae:1782.54
# [26]	train-mae:1727.51	eval-mae:1751.77
# [27]	train-mae:1697.73	eval-mae:1722.17
# [28]	train-mae:1669.52	eval-mae:1693.99
# [29]	train-mae:1642.85	eval-mae:1667.25
# [30]	train-mae:1617.52	eval-mae:1642.03
# [31]	train-mae:1593.47	eval-mae:1618.04
# [32]	train-mae:1570.84	eval-mae:1595.24
# [33]	train-mae:1549.31	eval-mae:1573.78
# [34]	train-mae:1528.6	eval-mae:1553.28
# [35]	train-mae:1509.02	eval-mae:1533.85
# [36]	train-mae:1490.5	eval-mae:1515.3
# [37]	train-mae:1472.62	eval-mae:1497.51
# [38]	train-mae:1455.7	eval-mae:1480.7
# [39]	train-mae:1439.7	eval-mae:1465.06
# [40]	train-mae:1424.41	eval-mae:1449.92
# [41]	train-mae:1409.77	eval-mae:1435.42
# [42]	train-mae:1395.88	eval-mae:1421.87
# [43]	train-mae:1382.69	eval-mae:1408.79
# [44]	train-mae:1370.27	eval-mae:1396.49
# [45]	train-mae:1358.47	eval-mae:1384.99
# [46]	train-mae:1347.18	eval-mae:1373.89
# [47]	train-mae:1336.55	eval-mae:1363.42
# [48]	train-mae:1326.4	eval-mae:1353.41
# [49]	train-mae:1316.61	eval-mae:1343.92
# [50]	train-mae:1307.38	eval-mae:1334.78
# [51]	train-mae:1298.63	eval-mae:1326.3
# [52]	train-mae:1290.25	eval-mae:1318.19
# [53]	train-mae:1282.4	eval-mae:1310.63
# [54]	train-mae:1274.92	eval-mae:1303.61
# [55]	train-mae:1267.85	eval-mae:1296.98
# [56]	train-mae:1260.88	eval-mae:1290.32
# [57]	train-mae:1254.38	eval-mae:1284.25
# [58]	train-mae:1248.19	eval-mae:1278.51
# [59]	train-mae:1242.36	eval-mae:1273.17
# [60]	train-mae:1236.82	eval-mae:1268.01
# [61]	train-mae:1231.61	eval-mae:1263.26
# [62]	train-mae:1226.6	eval-mae:1258.73
# [63]	train-mae:1221.61	eval-mae:1254.13
# [64]	train-mae:1217.06	eval-mae:1249.85
# [65]	train-mae:1212.52	eval-mae:1245.66
# [66]	train-mae:1208.11	eval-mae:1241.67
# [67]	train-mae:1204.32	eval-mae:1238.14
# [68]	train-mae:1200.62	eval-mae:1234.7
# [69]	train-mae:1196.99	eval-mae:1231.49
# [70]	train-mae:1193.43	eval-mae:1228.42
# [71]	train-mae:1190.09	eval-mae:1225.61
# [72]	train-mae:1187	eval-mae:1222.81
# [73]	train-mae:1183.94	eval-mae:1220.04
# [74]	train-mae:1181.12	eval-mae:1217.45
# [75]	train-mae:1178.31	eval-mae:1214.94
# [76]	train-mae:1175.73	eval-mae:1212.68
# [77]	train-mae:1173.27	eval-mae:1210.43
# [78]	train-mae:1170.85	eval-mae:1208.32
# [79]	train-mae:1168.48	eval-mae:1206.24
# [80]	train-mae:1166.4	eval-mae:1204.31
# [81]	train-mae:1164.01	eval-mae:1202.2
# [82]	train-mae:1162.22	eval-mae:1200.62
# [83]	train-mae:1160.43	eval-mae:1198.99
# [84]	train-mae:1158.66	eval-mae:1197.51
# [85]	train-mae:1156.7	eval-mae:1195.88
# [86]	train-mae:1155.07	eval-mae:1194.54
# [87]	train-mae:1153.37	eval-mae:1193.35
# [88]	train-mae:1151.69	eval-mae:1192.05
# [89]	train-mae:1150.13	eval-mae:1190.78
# [90]	train-mae:1148.79	eval-mae:1189.65
# [91]	train-mae:1147.43	eval-mae:1188.49
# [92]	train-mae:1146.22	eval-mae:1187.41
# [93]	train-mae:1144.91	eval-mae:1186.44
# [94]	train-mae:1143.63	eval-mae:1185.38
# [95]	train-mae:1142.49	eval-mae:1184.33
# [96]	train-mae:1141.42	eval-mae:1183.45
# [97]	train-mae:1140.2	eval-mae:1182.48
# [98]	train-mae:1139.31	eval-mae:1181.76
# [99]	train-mae:1138.01	eval-mae:1180.84
# [100]	train-mae:1137.04	eval-mae:1180.14
# [101]	train-mae:1136.12	eval-mae:1179.53
# [102]	train-mae:1135.01	eval-mae:1178.73
# [103]	train-mae:1134.17	eval-mae:1178.04
# [104]	train-mae:1133.41	eval-mae:1177.28
# [105]	train-mae:1132.5	eval-mae:1176.61
# [106]	train-mae:1131.81	eval-mae:1176.05
# [107]	train-mae:1130.94	eval-mae:1175.37
# [108]	train-mae:1130.26	eval-mae:1174.94
# [109]	train-mae:1129.26	eval-mae:1174.21
# [110]	train-mae:1128.55	eval-mae:1173.61
# [111]	train-mae:1127.78	eval-mae:1173.08
# [112]	train-mae:1127.08	eval-mae:1172.54
# [113]	train-mae:1126.4	eval-mae:1172.11
# [114]	train-mae:1125.65	eval-mae:1171.66
# [115]	train-mae:1125.17	eval-mae:1171.36
# [116]	train-mae:1124.42	eval-mae:1170.87
# [117]	train-mae:1123.57	eval-mae:1170.46
# [118]	train-mae:1122.93	eval-mae:1170.03
# [119]	train-mae:1122.43	eval-mae:1169.61
# [120]	train-mae:1121.76	eval-mae:1169.23
# [121]	train-mae:1121.39	eval-mae:1168.88
# [122]	train-mae:1121.04	eval-mae:1168.6
# [123]	train-mae:1120.6	eval-mae:1168.17
# [124]	train-mae:1120.05	eval-mae:1167.81
# [125]	train-mae:1119.69	eval-mae:1167.57
# [126]	train-mae:1119.01	eval-mae:1167.18
# [127]	train-mae:1118.42	eval-mae:1166.86
# [128]	train-mae:1118.11	eval-mae:1166.7
# [129]	train-mae:1117.71	eval-mae:1166.45
# [130]	train-mae:1117.33	eval-mae:1166.11
# [131]	train-mae:1116.91	eval-mae:1165.84
# [132]	train-mae:1116.33	eval-mae:1165.51
# [133]	train-mae:1115.93	eval-mae:1165.17
# [134]	train-mae:1115.53	eval-mae:1164.95
# [135]	train-mae:1115.2	eval-mae:1164.7
# [136]	train-mae:1114.93	eval-mae:1164.48
# [137]	train-mae:1114.47	eval-mae:1164.21
# [138]	train-mae:1114.02	eval-mae:1163.95
# [139]	train-mae:1113.75	eval-mae:1163.74
# [140]	train-mae:1113.46	eval-mae:1163.45
# [141]	train-mae:1113.12	eval-mae:1163.33
# [142]	train-mae:1112.54	eval-mae:1162.98
# [143]	train-mae:1111.99	eval-mae:1162.64
# [144]	train-mae:1111.43	eval-mae:1162.44
# [145]	train-mae:1110.95	eval-mae:1162.02
# [146]	train-mae:1110.53	eval-mae:1161.86
# [147]	train-mae:1110.27	eval-mae:1161.68
# [148]	train-mae:1109.82	eval-mae:1161.64
# [149]	train-mae:1109.52	eval-mae:1161.46
# [150]	train-mae:1109.12	eval-mae:1161.16
# [151]	train-mae:1108.63	eval-mae:1161
# [152]	train-mae:1108.34	eval-mae:1160.89
# [153]	train-mae:1108.11	eval-mae:1160.75
# [154]	train-mae:1107.77	eval-mae:1160.58
# [155]	train-mae:1107.28	eval-mae:1160.32
# [156]	train-mae:1106.93	eval-mae:1160.04
# [157]	train-mae:1106.66	eval-mae:1159.81
# [158]	train-mae:1106.2	eval-mae:1159.5
# [159]	train-mae:1105.81	eval-mae:1159.3
# [160]	train-mae:1105.56	eval-mae:1159.18
# [161]	train-mae:1105.16	eval-mae:1158.94
# [162]	train-mae:1104.74	eval-mae:1158.8
# [163]	train-mae:1104.37	eval-mae:1158.63
# [164]	train-mae:1104.15	eval-mae:1158.49
# [165]	train-mae:1103.96	eval-mae:1158.32
# [166]	train-mae:1103.77	eval-mae:1158.25
# [167]	train-mae:1103.4	eval-mae:1158.13
# [168]	train-mae:1103.07	eval-mae:1157.93
# [169]	train-mae:1102.8	eval-mae:1157.81
# [170]	train-mae:1102.49	eval-mae:1157.61
# [171]	train-mae:1102.06	eval-mae:1157.49
# [172]	train-mae:1101.83	eval-mae:1157.27
# [173]	train-mae:1101.71	eval-mae:1157.21
# [174]	train-mae:1101.24	eval-mae:1157.12
# [175]	train-mae:1100.99	eval-mae:1156.98
# [176]	train-mae:1100.82	eval-mae:1156.92
# [177]	train-mae:1100.51	eval-mae:1156.59
# [178]	train-mae:1100.11	eval-mae:1156.33
# [179]	train-mae:1099.79	eval-mae:1156.2
# [180]	train-mae:1099.59	eval-mae:1156.05
# [181]	train-mae:1099.49	eval-mae:1155.99
# [182]	train-mae:1099.28	eval-mae:1155.88
# [183]	train-mae:1099.02	eval-mae:1155.81
# [184]	train-mae:1098.89	eval-mae:1155.78
# [185]	train-mae:1098.55	eval-mae:1155.6
# [186]	train-mae:1098.25	eval-mae:1155.42
# [187]	train-mae:1097.77	eval-mae:1155.23
# [188]	train-mae:1097.45	eval-mae:1155.14
# [189]	train-mae:1097.18	eval-mae:1155.04
# [190]	train-mae:1097	eval-mae:1154.89
# [191]	train-mae:1096.87	eval-mae:1154.71
# [192]	train-mae:1096.72	eval-mae:1154.61
# [193]	train-mae:1096.51	eval-mae:1154.55
# [194]	train-mae:1096.32	eval-mae:1154.48
# [195]	train-mae:1096.11	eval-mae:1154.34
# [196]	train-mae:1095.9	eval-mae:1154.18
# [197]	train-mae:1095.66	eval-mae:1154.13
# [198]	train-mae:1095.42	eval-mae:1154.1
# [199]	train-mae:1095	eval-mae:1153.98
# [200]	train-mae:1094.82	eval-mae:1153.9
# [201]	train-mae:1094.56	eval-mae:1153.78
# [202]	train-mae:1094.43	eval-mae:1153.66
# [203]	train-mae:1094.36	eval-mae:1153.6
# [204]	train-mae:1094.26	eval-mae:1153.57
# [205]	train-mae:1094.12	eval-mae:1153.52
# [206]	train-mae:1093.83	eval-mae:1153.39
# [207]	train-mae:1093.72	eval-mae:1153.36
# [208]	train-mae:1093.52	eval-mae:1153.33
# [209]	train-mae:1093.38	eval-mae:1153.26
# [210]	train-mae:1092.96	eval-mae:1153.11
# [211]	train-mae:1092.81	eval-mae:1153.18
# [212]	train-mae:1092.66	eval-mae:1153.14
# [213]	train-mae:1092.22	eval-mae:1153
# [214]	train-mae:1092.13	eval-mae:1152.94
# [215]	train-mae:1091.95	eval-mae:1152.74
# [216]	train-mae:1091.84	eval-mae:1152.65
# [217]	train-mae:1091.63	eval-mae:1152.46
# [218]	train-mae:1091.34	eval-mae:1152.34
# [219]	train-mae:1091.14	eval-mae:1152.23
# [220]	train-mae:1091.03	eval-mae:1152.16
# [221]	train-mae:1090.9	eval-mae:1152.16
# [222]	train-mae:1090.61	eval-mae:1152.02
# [223]	train-mae:1090.31	eval-mae:1151.86
# [224]	train-mae:1090.17	eval-mae:1151.84
# [225]	train-mae:1090.04	eval-mae:1151.83
# [226]	train-mae:1089.78	eval-mae:1151.8
# [227]	train-mae:1089.45	eval-mae:1151.65
# [228]	train-mae:1089.11	eval-mae:1151.36
# [229]	train-mae:1089.03	eval-mae:1151.28
# [230]	train-mae:1088.8	eval-mae:1151.24
# [231]	train-mae:1088.62	eval-mae:1151.16
# [232]	train-mae:1088.49	eval-mae:1151.12
# [233]	train-mae:1088.27	eval-mae:1151.05
# [234]	train-mae:1088	eval-mae:1150.83
# [235]	train-mae:1087.67	eval-mae:1150.77
# [236]	train-mae:1087.55	eval-mae:1150.69
# [237]	train-mae:1087.39	eval-mae:1150.55
# [238]	train-mae:1087.19	eval-mae:1150.54
# [239]	train-mae:1086.92	eval-mae:1150.5
# [240]	train-mae:1086.73	eval-mae:1150.47
# [241]	train-mae:1086.57	eval-mae:1150.33
# [242]	train-mae:1086.2	eval-mae:1150.22
# [243]	train-mae:1086.04	eval-mae:1150.15
# [244]	train-mae:1085.89	eval-mae:1150.02
# [245]	train-mae:1085.79	eval-mae:1150.03
# [246]	train-mae:1085.48	eval-mae:1149.91
# [247]	train-mae:1085.33	eval-mae:1149.85
# [248]	train-mae:1085.24	eval-mae:1149.85
# [249]	train-mae:1085.07	eval-mae:1149.77
# [250]	train-mae:1084.64	eval-mae:1149.51
# [251]	train-mae:1084.47	eval-mae:1149.44
# [252]	train-mae:1084.29	eval-mae:1149.38
# [253]	train-mae:1084.17	eval-mae:1149.41
# [254]	train-mae:1084.03	eval-mae:1149.23
# [255]	train-mae:1083.82	eval-mae:1149.04
# [256]	train-mae:1083.51	eval-mae:1149.05
# [257]	train-mae:1083.41	eval-mae:1149.01
# [258]	train-mae:1083.21	eval-mae:1148.93
# [259]	train-mae:1083.01	eval-mae:1148.88
# [260]	train-mae:1082.94	eval-mae:1148.89
# [261]	train-mae:1082.79	eval-mae:1148.82
# [262]	train-mae:1082.44	eval-mae:1148.54
# [263]	train-mae:1082.25	eval-mae:1148.48
# [264]	train-mae:1082.01	eval-mae:1148.48
# [265]	train-mae:1081.8	eval-mae:1148.39
# [266]	train-mae:1081.7	eval-mae:1148.36
# [267]	train-mae:1081.59	eval-mae:1148.32
# [268]	train-mae:1081.45	eval-mae:1148.25
# [269]	train-mae:1081.31	eval-mae:1148.15
# [270]	train-mae:1081.14	eval-mae:1148.12
# [271]	train-mae:1080.93	eval-mae:1148.05
# [272]	train-mae:1080.79	eval-mae:1147.96
# [273]	train-mae:1080.34	eval-mae:1147.92
# [274]	train-mae:1080.15	eval-mae:1147.77
# [275]	train-mae:1079.81	eval-mae:1147.69
# [276]	train-mae:1079.7	eval-mae:1147.65
# [277]	train-mae:1079.38	eval-mae:1147.5
# [278]	train-mae:1079.22	eval-mae:1147.49
# [279]	train-mae:1079.09	eval-mae:1147.41
# [280]	train-mae:1078.84	eval-mae:1147.28
# [281]	train-mae:1078.62	eval-mae:1147.15
# [282]	train-mae:1078.4	eval-mae:1147.05
# [283]	train-mae:1078.27	eval-mae:1147.02
# [284]	train-mae:1078.1	eval-mae:1146.95
# [285]	train-mae:1077.98	eval-mae:1146.91
# [286]	train-mae:1077.91	eval-mae:1146.89
# [287]	train-mae:1077.84	eval-mae:1146.83
# [288]	train-mae:1077.53	eval-mae:1146.9
# [289]	train-mae:1077.37	eval-mae:1146.81
# [290]	train-mae:1077.15	eval-mae:1146.78
# [291]	train-mae:1077.02	eval-mae:1146.74
# [292]	train-mae:1076.73	eval-mae:1146.6
# [293]	train-mae:1076.62	eval-mae:1146.63
# [294]	train-mae:1076.51	eval-mae:1146.61
# [295]	train-mae:1076.08	eval-mae:1146.57
# [296]	train-mae:1075.85	eval-mae:1146.61
# [297]	train-mae:1075.72	eval-mae:1146.62
# [298]	train-mae:1075.42	eval-mae:1146.54
# [299]	train-mae:1075.29	eval-mae:1146.52
# [300]	train-mae:1075.14	eval-mae:1146.47
# [301]	train-mae:1074.88	eval-mae:1146.35
# [302]	train-mae:1074.69	eval-mae:1146.34
# [303]	train-mae:1074.57	eval-mae:1146.37
# [304]	train-mae:1074.44	eval-mae:1146.45
# [305]	train-mae:1074.28	eval-mae:1146.41
# [306]	train-mae:1074.07	eval-mae:1146.3
# [307]	train-mae:1073.9	eval-mae:1146.38
# [308]	train-mae:1073.78	eval-mae:1146.3
# [309]	train-mae:1073.62	eval-mae:1146.27
# [310]	train-mae:1073.51	eval-mae:1146.27
# [311]	train-mae:1073.34	eval-mae:1146.18
# [312]	train-mae:1073.2	eval-mae:1146.06
# [313]	train-mae:1072.94	eval-mae:1145.99
# [314]	train-mae:1072.82	eval-mae:1145.88
# [315]	train-mae:1072.67	eval-mae:1145.74
# [316]	train-mae:1072.46	eval-mae:1145.71
# [317]	train-mae:1072.3	eval-mae:1145.75
# [318]	train-mae:1072.13	eval-mae:1145.73
# [319]	train-mae:1072.04	eval-mae:1145.74
# [320]	train-mae:1071.79	eval-mae:1145.69
# [321]	train-mae:1071.57	eval-mae:1145.67
# [322]	train-mae:1071.36	eval-mae:1145.7
# [323]	train-mae:1071.08	eval-mae:1145.74
# [324]	train-mae:1070.7	eval-mae:1145.63
# [325]	train-mae:1070.5	eval-mae:1145.66
# [326]	train-mae:1070.35	eval-mae:1145.68
# [327]	train-mae:1070.14	eval-mae:1145.58
# [328]	train-mae:1069.94	eval-mae:1145.45
# [329]	train-mae:1069.73	eval-mae:1145.5
# [330]	train-mae:1069.55	eval-mae:1145.48
# [331]	train-mae:1069.46	eval-mae:1145.53
# [332]	train-mae:1069.3	eval-mae:1145.44
# [333]	train-mae:1069.18	eval-mae:1145.44
# [334]	train-mae:1068.89	eval-mae:1145.49
# [335]	train-mae:1068.63	eval-mae:1145.47
# [336]	train-mae:1068.41	eval-mae:1145.47
# [337]	train-mae:1068.32	eval-mae:1145.37
# [338]	train-mae:1068.02	eval-mae:1145.33
# [339]	train-mae:1067.97	eval-mae:1145.25
# [340]	train-mae:1067.88	eval-mae:1145.24
# [341]	train-mae:1067.79	eval-mae:1145.25
# [342]	train-mae:1067.52	eval-mae:1145.24
# [343]	train-mae:1067.35	eval-mae:1145.15
# [344]	train-mae:1067.09	eval-mae:1145.01
# [345]	train-mae:1066.89	eval-mae:1144.95
# [346]	train-mae:1066.79	eval-mae:1144.85
# [347]	train-mae:1066.58	eval-mae:1144.81
# [348]	train-mae:1066.38	eval-mae:1144.68
# [349]	train-mae:1066.19	eval-mae:1144.62
# [350]	train-mae:1066	eval-mae:1144.6
# [351]	train-mae:1065.88	eval-mae:1144.62
# [352]	train-mae:1065.57	eval-mae:1144.54
# [353]	train-mae:1065.44	eval-mae:1144.57
# [354]	train-mae:1065.04	eval-mae:1144.5
# [355]	train-mae:1064.95	eval-mae:1144.48
# [356]	train-mae:1064.88	eval-mae:1144.44
# [357]	train-mae:1064.78	eval-mae:1144.33
# [358]	train-mae:1064.68	eval-mae:1144.26
# [359]	train-mae:1064.6	eval-mae:1144.26
# [360]	train-mae:1064.46	eval-mae:1144.29
# [361]	train-mae:1064.22	eval-mae:1144.28
# [362]	train-mae:1064.16	eval-mae:1144.22
# [363]	train-mae:1063.83	eval-mae:1144.08
# [364]	train-mae:1063.74	eval-mae:1144.05
# [365]	train-mae:1063.67	eval-mae:1144.02
# [366]	train-mae:1063.52	eval-mae:1143.95
# [367]	train-mae:1063.35	eval-mae:1143.95
# [368]	train-mae:1063.15	eval-mae:1143.97
# [369]	train-mae:1062.95	eval-mae:1143.94
# [370]	train-mae:1062.82	eval-mae:1143.92
# [371]	train-mae:1062.73	eval-mae:1143.86
# [372]	train-mae:1062.41	eval-mae:1143.9
# [373]	train-mae:1062.29	eval-mae:1143.84
# [374]	train-mae:1062.04	eval-mae:1143.68
# [375]	train-mae:1061.91	eval-mae:1143.59
# [376]	train-mae:1061.7	eval-mae:1143.45
# [377]	train-mae:1061.58	eval-mae:1143.35
# [378]	train-mae:1061.42	eval-mae:1143.36
# [379]	train-mae:1061.3	eval-mae:1143.27
# [380]	train-mae:1061.1	eval-mae:1143.27
# [381]	train-mae:1060.9	eval-mae:1143.13
# [382]	train-mae:1060.77	eval-mae:1143.12
# [383]	train-mae:1060.71	eval-mae:1143.14
# [384]	train-mae:1060.59	eval-mae:1143.11
# [385]	train-mae:1060.45	eval-mae:1143.06
# [386]	train-mae:1060.32	eval-mae:1143.1
# [387]	train-mae:1060.24	eval-mae:1143.11
# [388]	train-mae:1059.91	eval-mae:1142.93
# [389]	train-mae:1059.73	eval-mae:1142.9
# [390]	train-mae:1059.55	eval-mae:1142.88
# [391]	train-mae:1059.39	eval-mae:1142.82
# [392]	train-mae:1059.31	eval-mae:1142.83
# [393]	train-mae:1059.19	eval-mae:1142.8
# [394]	train-mae:1059.1	eval-mae:1142.76
# [395]	train-mae:1059.01	eval-mae:1142.76
# [396]	train-mae:1058.93	eval-mae:1142.76
# [397]	train-mae:1058.85	eval-mae:1142.74
# [398]	train-mae:1058.68	eval-mae:1142.78
# [399]	train-mae:1058.61	eval-mae:1142.68
# [400]	train-mae:1058.55	eval-mae:1142.64
# [401]	train-mae:1058.28	eval-mae:1142.79
# [402]	train-mae:1058.1	eval-mae:1142.82
# [403]	train-mae:1057.91	eval-mae:1142.88
# [404]	train-mae:1057.82	eval-mae:1142.84
# [405]	train-mae:1057.55	eval-mae:1142.79
# [406]	train-mae:1057.43	eval-mae:1142.8
# [407]	train-mae:1057.21	eval-mae:1142.76
# [408]	train-mae:1057.13	eval-mae:1142.77
# [409]	train-mae:1057.05	eval-mae:1142.73
# [410]	train-mae:1056.86	eval-mae:1142.66
# [411]	train-mae:1056.77	eval-mae:1142.66
# [412]	train-mae:1056.6	eval-mae:1142.65
# [413]	train-mae:1056.45	eval-mae:1142.61
# [414]	train-mae:1056.34	eval-mae:1142.52
# [415]	train-mae:1056.25	eval-mae:1142.49
# [416]	train-mae:1056.12	eval-mae:1142.54
# [417]	train-mae:1055.92	eval-mae:1142.47
# [418]	train-mae:1055.77	eval-mae:1142.45
# [419]	train-mae:1055.55	eval-mae:1142.46
# [420]	train-mae:1055.34	eval-mae:1142.37
# [421]	train-mae:1055.12	eval-mae:1142.3
# [422]	train-mae:1055.03	eval-mae:1142.3
# [423]	train-mae:1054.92	eval-mae:1142.32
# [424]	train-mae:1054.84	eval-mae:1142.35
# [425]	train-mae:1054.75	eval-mae:1142.36
# [426]	train-mae:1054.62	eval-mae:1142.28
# [427]	train-mae:1054.47	eval-mae:1142.22
# [428]	train-mae:1054.44	eval-mae:1142.23
# [429]	train-mae:1054.3	eval-mae:1142.29
# [430]	train-mae:1054.24	eval-mae:1142.35
# [431]	train-mae:1054.03	eval-mae:1142.35
# [432]	train-mae:1053.83	eval-mae:1142.27
# [433]	train-mae:1053.69	eval-mae:1142.21
# [434]	train-mae:1053.45	eval-mae:1142.23
# [435]	train-mae:1053.27	eval-mae:1142.11
# [436]	train-mae:1053.11	eval-mae:1142.04
# [437]	train-mae:1053.01	eval-mae:1142.05
# [438]	train-mae:1052.87	eval-mae:1141.99
# [439]	train-mae:1052.74	eval-mae:1142.03
# [440]	train-mae:1052.58	eval-mae:1142.02
# [441]	train-mae:1052.42	eval-mae:1142.01
# [442]	train-mae:1052.21	eval-mae:1141.99
# [443]	train-mae:1052.16	eval-mae:1141.98
# [444]	train-mae:1051.97	eval-mae:1142.02
# [445]	train-mae:1051.86	eval-mae:1142.06
# [446]	train-mae:1051.69	eval-mae:1142.05
# [447]	train-mae:1051.56	eval-mae:1142.03
# [448]	train-mae:1051.39	eval-mae:1141.91
# [449]	train-mae:1051.32	eval-mae:1141.85
# [450]	train-mae:1051.29	eval-mae:1141.83
# [451]	train-mae:1051.2	eval-mae:1141.73
# [452]	train-mae:1050.97	eval-mae:1141.76
# [453]	train-mae:1050.92	eval-mae:1141.78
# [454]	train-mae:1050.79	eval-mae:1141.81
# [455]	train-mae:1050.63	eval-mae:1141.74
# [456]	train-mae:1050.34	eval-mae:1141.51
# [457]	train-mae:1050.19	eval-mae:1141.53
# [458]	train-mae:1050	eval-mae:1141.48
# [459]	train-mae:1049.8	eval-mae:1141.48
# [460]	train-mae:1049.58	eval-mae:1141.46
# [461]	train-mae:1049.48	eval-mae:1141.49
# [462]	train-mae:1049.29	eval-mae:1141.51
# [463]	train-mae:1049.24	eval-mae:1141.47
# [464]	train-mae:1049.15	eval-mae:1141.51
# [465]	train-mae:1049	eval-mae:1141.45
# [466]	train-mae:1048.91	eval-mae:1141.44
# [467]	train-mae:1048.81	eval-mae:1141.44
# [468]	train-mae:1048.69	eval-mae:1141.38
# [469]	train-mae:1048.54	eval-mae:1141.35
# [470]	train-mae:1048.33	eval-mae:1141.32
# [471]	train-mae:1048.27	eval-mae:1141.29
# [472]	train-mae:1048.15	eval-mae:1141.25
# [473]	train-mae:1048.02	eval-mae:1141.3
# [474]	train-mae:1047.93	eval-mae:1141.28
# [475]	train-mae:1047.76	eval-mae:1141.21
# [476]	train-mae:1047.66	eval-mae:1141.2
# [477]	train-mae:1047.41	eval-mae:1141.42
# [478]	train-mae:1047.33	eval-mae:1141.39
# [479]	train-mae:1047.27	eval-mae:1141.4
# [480]	train-mae:1047.15	eval-mae:1141.35
# [481]	train-mae:1047.06	eval-mae:1141.37
# [482]	train-mae:1047.01	eval-mae:1141.38
# [483]	train-mae:1046.89	eval-mae:1141.33
# [484]	train-mae:1046.72	eval-mae:1141.23
# [485]	train-mae:1046.52	eval-mae:1141.33
# [486]	train-mae:1046.48	eval-mae:1141.31
# [487]	train-mae:1046.34	eval-mae:1141.3
# [488]	train-mae:1046.15	eval-mae:1141.31
# [489]	train-mae:1046.01	eval-mae:1141.38
# [490]	train-mae:1045.89	eval-mae:1141.37
# [491]	train-mae:1045.75	eval-mae:1141.22
# [492]	train-mae:1045.57	eval-mae:1141.25
# [493]	train-mae:1045.54	eval-mae:1141.25
# [494]	train-mae:1045.3	eval-mae:1141.25
# [495]	train-mae:1045.25	eval-mae:1141.23
# [496]	train-mae:1045.01	eval-mae:1141.17
# [497]	train-mae:1044.94	eval-mae:1141.13
# [498]	train-mae:1044.88	eval-mae:1141.1
# [499]	train-mae:1044.76	eval-mae:1141.08
# [500]	train-mae:1044.7	eval-mae:1141.04
# [501]	train-mae:1044.61	eval-mae:1141.06
# [502]	train-mae:1044.42	eval-mae:1141.04
# [503]	train-mae:1044.3	eval-mae:1141.03
# [504]	train-mae:1044.21	eval-mae:1141.04
# [505]	train-mae:1044.14	eval-mae:1141.07
# [506]	train-mae:1044.03	eval-mae:1141.06
# [507]	train-mae:1043.86	eval-mae:1141.1
# [508]	train-mae:1043.76	eval-mae:1141.07
# [509]	train-mae:1043.68	eval-mae:1141.05
# [510]	train-mae:1043.52	eval-mae:1141.03
# [511]	train-mae:1043.42	eval-mae:1141.01
# [512]	train-mae:1043.26	eval-mae:1141.06
# [513]	train-mae:1043.02	eval-mae:1141
# [514]	train-mae:1042.86	eval-mae:1141.06
# [515]	train-mae:1042.73	eval-mae:1140.97
# [516]	train-mae:1042.6	eval-mae:1140.85
# [517]	train-mae:1042.51	eval-mae:1140.85
# [518]	train-mae:1042.38	eval-mae:1140.87
# [519]	train-mae:1042.31	eval-mae:1140.88
# [520]	train-mae:1042.19	eval-mae:1140.85
# [521]	train-mae:1042.01	eval-mae:1140.79
# [522]	train-mae:1041.93	eval-mae:1140.79
# [523]	train-mae:1041.84	eval-mae:1140.8
# [524]	train-mae:1041.75	eval-mae:1140.81
# [525]	train-mae:1041.62	eval-mae:1140.85
# [526]	train-mae:1041.42	eval-mae:1140.88
# [527]	train-mae:1041.27	eval-mae:1140.94
# [528]	train-mae:1041.19	eval-mae:1140.98
# [529]	train-mae:1040.98	eval-mae:1140.99
# [530]	train-mae:1040.8	eval-mae:1141
# [531]	train-mae:1040.63	eval-mae:1141.04
# [532]	train-mae:1040.55	eval-mae:1141
# [533]	train-mae:1040.33	eval-mae:1141.06
# [534]	train-mae:1040.03	eval-mae:1141.06
# [535]	train-mae:1039.88	eval-mae:1141.12
# [536]	train-mae:1039.77	eval-mae:1141.15
# [537]	train-mae:1039.62	eval-mae:1141.08
# [538]	train-mae:1039.5	eval-mae:1141.05
# [539]	train-mae:1039.34	eval-mae:1140.99
# [540]	train-mae:1039.25	eval-mae:1141.09
# [541]	train-mae:1039.15	eval-mae:1141.08
# [542]	train-mae:1038.99	eval-mae:1141.04
# [543]	train-mae:1038.84	eval-mae:1141.02
# [544]	train-mae:1038.77	eval-mae:1141.02
# [545]	train-mae:1038.62	eval-mae:1141
# [546]	train-mae:1038.39	eval-mae:1140.97
# [547]	train-mae:1038.26	eval-mae:1140.99
# [548]	train-mae:1038.13	eval-mae:1141
# [549]	train-mae:1038.03	eval-mae:1140.97
# [550]	train-mae:1037.79	eval-mae:1140.86
# [551]	train-mae:1037.63	eval-mae:1140.86
# [552]	train-mae:1037.56	eval-mae:1140.8
# [553]	train-mae:1037.4	eval-mae:1140.71
# [554]	train-mae:1037.28	eval-mae:1140.69
# [555]	train-mae:1037.13	eval-mae:1140.58
# [556]	train-mae:1037.08	eval-mae:1140.58
# [557]	train-mae:1036.99	eval-mae:1140.6
# [558]	train-mae:1036.92	eval-mae:1140.62
# [559]	train-mae:1036.79	eval-mae:1140.58
# [560]	train-mae:1036.62	eval-mae:1140.57
# [561]	train-mae:1036.48	eval-mae:1140.57
# [562]	train-mae:1036.34	eval-mae:1140.6
# [563]	train-mae:1036.21	eval-mae:1140.64
# [564]	train-mae:1036.09	eval-mae:1140.68
# [565]	train-mae:1035.99	eval-mae:1140.65
# [566]	train-mae:1035.89	eval-mae:1140.62
# [567]	train-mae:1035.76	eval-mae:1140.62
# [568]	train-mae:1035.57	eval-mae:1140.64
# [569]	train-mae:1035.52	eval-mae:1140.62
# [570]	train-mae:1035.35	eval-mae:1140.6
# [571]	train-mae:1035.2	eval-mae:1140.58
# [572]	train-mae:1035.04	eval-mae:1140.53
# [573]	train-mae:1034.84	eval-mae:1140.53
# [574]	train-mae:1034.74	eval-mae:1140.51
# [575]	train-mae:1034.66	eval-mae:1140.54
# [576]	train-mae:1034.55	eval-mae:1140.54
# [577]	train-mae:1034.38	eval-mae:1140.46
# [578]	train-mae:1034.34	eval-mae:1140.47
# [579]	train-mae:1034.22	eval-mae:1140.47
# [580]	train-mae:1034.08	eval-mae:1140.37
# [581]	train-mae:1034.01	eval-mae:1140.34
# [582]	train-mae:1033.97	eval-mae:1140.36
# [583]	train-mae:1033.8	eval-mae:1140.32
# [584]	train-mae:1033.69	eval-mae:1140.31
# [585]	train-mae:1033.63	eval-mae:1140.3
# [586]	train-mae:1033.56	eval-mae:1140.24
# [587]	train-mae:1033.54	eval-mae:1140.2
# [588]	train-mae:1033.34	eval-mae:1140.18
# [589]	train-mae:1033.26	eval-mae:1140.14
# [590]	train-mae:1033.15	eval-mae:1140.19
# [591]	train-mae:1033.06	eval-mae:1140.21
# [592]	train-mae:1033.05	eval-mae:1140.18
# [593]	train-mae:1032.86	eval-mae:1140.21
# [594]	train-mae:1032.73	eval-mae:1140.19
# [595]	train-mae:1032.6	eval-mae:1140.29
# [596]	train-mae:1032.55	eval-mae:1140.3
# [597]	train-mae:1032.46	eval-mae:1140.3
# [598]	train-mae:1032.32	eval-mae:1140.24
# [599]	train-mae:1032.25	eval-mae:1140.25
# [600]	train-mae:1032.21	eval-mae:1140.26
# [601]	train-mae:1032.08	eval-mae:1140.3
# [602]	train-mae:1031.96	eval-mae:1140.23
# [603]	train-mae:1031.86	eval-mae:1140.25
# [604]	train-mae:1031.72	eval-mae:1140.26
# [605]	train-mae:1031.68	eval-mae:1140.22
# [606]	train-mae:1031.52	eval-mae:1140.25
# [607]	train-mae:1031.4	eval-mae:1140.24
# [608]	train-mae:1031.37	eval-mae:1140.22
# [609]	train-mae:1031.28	eval-mae:1140.2
# [610]	train-mae:1031.17	eval-mae:1140.15
# [611]	train-mae:1030.97	eval-mae:1140.11
# [612]	train-mae:1030.83	eval-mae:1140.24
# [613]	train-mae:1030.79	eval-mae:1140.24
# [614]	train-mae:1030.63	eval-mae:1140.28
# [615]	train-mae:1030.5	eval-mae:1140.3
# [616]	train-mae:1030.41	eval-mae:1140.31
# [617]	train-mae:1030.28	eval-mae:1140.27
# [618]	train-mae:1030.22	eval-mae:1140.25
# [619]	train-mae:1030.15	eval-mae:1140.3
# [620]	train-mae:1030.02	eval-mae:1140.24
# [621]	train-mae:1029.93	eval-mae:1140.27
# [622]	train-mae:1029.83	eval-mae:1140.22
# [623]	train-mae:1029.73	eval-mae:1140.25
# [624]	train-mae:1029.61	eval-mae:1140.22
# [625]	train-mae:1029.46	eval-mae:1140.17
# [626]	train-mae:1029.39	eval-mae:1140.15
# [627]	train-mae:1029.26	eval-mae:1140.22
# [628]	train-mae:1029.17	eval-mae:1140.22
# [629]	train-mae:1029.01	eval-mae:1140.26
# [630]	train-mae:1028.87	eval-mae:1140.25
# [631]	train-mae:1028.78	eval-mae:1140.31
# [632]	train-mae:1028.59	eval-mae:1140.3
# [633]	train-mae:1028.51	eval-mae:1140.34
# [634]	train-mae:1028.41	eval-mae:1140.24
# [635]	train-mae:1028.36	eval-mae:1140.24
# [636]	train-mae:1028.2	eval-mae:1140.28
# [637]	train-mae:1028.07	eval-mae:1140.19
# [638]	train-mae:1027.81	eval-mae:1140.05
# [639]	train-mae:1027.61	eval-mae:1140.08
# [640]	train-mae:1027.53	eval-mae:1140.05
# [641]	train-mae:1027.45	eval-mae:1140.04
# [642]	train-mae:1027.3	eval-mae:1140.07
# [643]	train-mae:1027.14	eval-mae:1140.13
# [644]	train-mae:1026.98	eval-mae:1140.14
# [645]	train-mae:1026.95	eval-mae:1140.07
# [646]	train-mae:1026.8	eval-mae:1139.98
# [647]	train-mae:1026.73	eval-mae:1139.98
# [648]	train-mae:1026.64	eval-mae:1140
# [649]	train-mae:1026.58	eval-mae:1139.98
# [650]	train-mae:1026.29	eval-mae:1139.92
# [651]	train-mae:1026.19	eval-mae:1139.95
# [652]	train-mae:1026.03	eval-mae:1139.86
# [653]	train-mae:1025.86	eval-mae:1139.86
# [654]	train-mae:1025.78	eval-mae:1139.91
# [655]	train-mae:1025.61	eval-mae:1139.87
# [656]	train-mae:1025.47	eval-mae:1139.84
# [657]	train-mae:1025.39	eval-mae:1139.81
# [658]	train-mae:1025.27	eval-mae:1139.78
# [659]	train-mae:1025.19	eval-mae:1139.87
# [660]	train-mae:1025.09	eval-mae:1139.92
# [661]	train-mae:1024.96	eval-mae:1140.03
# [662]	train-mae:1024.82	eval-mae:1139.96
# [663]	train-mae:1024.73	eval-mae:1139.93
# [664]	train-mae:1024.67	eval-mae:1139.86
# [665]	train-mae:1024.56	eval-mae:1139.86
# [666]	train-mae:1024.38	eval-mae:1139.84
# [667]	train-mae:1024.28	eval-mae:1139.85
# [668]	train-mae:1024.17	eval-mae:1139.89
# [669]	train-mae:1024.02	eval-mae:1139.84
# [670]	train-mae:1023.96	eval-mae:1139.84
# [671]	train-mae:1023.9	eval-mae:1139.81
# [672]	train-mae:1023.83	eval-mae:1139.77
# [673]	train-mae:1023.74	eval-mae:1139.81
# [674]	train-mae:1023.65	eval-mae:1139.7
# [675]	train-mae:1023.49	eval-mae:1139.66
# [676]	train-mae:1023.36	eval-mae:1139.6
# [677]	train-mae:1023.18	eval-mae:1139.58
# [678]	train-mae:1023.11	eval-mae:1139.55
# [679]	train-mae:1022.97	eval-mae:1139.57
# [680]	train-mae:1022.84	eval-mae:1139.62
# [681]	train-mae:1022.69	eval-mae:1139.7
# [682]	train-mae:1022.54	eval-mae:1139.53
# [683]	train-mae:1022.37	eval-mae:1139.49
# [684]	train-mae:1022.3	eval-mae:1139.43
# [685]	train-mae:1022.24	eval-mae:1139.45
# [686]	train-mae:1022.06	eval-mae:1139.43
# [687]	train-mae:1021.89	eval-mae:1139.45
# [688]	train-mae:1021.72	eval-mae:1139.44
# [689]	train-mae:1021.61	eval-mae:1139.4
# [690]	train-mae:1021.47	eval-mae:1139.5
# [691]	train-mae:1021.34	eval-mae:1139.49
# [692]	train-mae:1021.22	eval-mae:1139.52
# [693]	train-mae:1021.07	eval-mae:1139.54
# [694]	train-mae:1020.98	eval-mae:1139.49
# [695]	train-mae:1020.81	eval-mae:1139.57
# [696]	train-mae:1020.64	eval-mae:1139.53
# [697]	train-mae:1020.5	eval-mae:1139.46
# [698]	train-mae:1020.34	eval-mae:1139.54
# [699]	train-mae:1020.23	eval-mae:1139.59
# [700]	train-mae:1020.19	eval-mae:1139.56
# [701]	train-mae:1019.99	eval-mae:1139.61
# [702]	train-mae:1019.94	eval-mae:1139.64
# [703]	train-mae:1019.81	eval-mae:1139.68
# [704]	train-mae:1019.71	eval-mae:1139.74
# [705]	train-mae:1019.6	eval-mae:1139.67
# [706]	train-mae:1019.42	eval-mae:1139.61
# [707]	train-mae:1019.26	eval-mae:1139.52
# [708]	train-mae:1019.15	eval-mae:1139.49
# [709]	train-mae:1019.1	eval-mae:1139.51
# [710]	train-mae:1019.01	eval-mae:1139.52
# [711]	train-mae:1018.94	eval-mae:1139.49
# [712]	train-mae:1018.89	eval-mae:1139.47
# [713]	train-mae:1018.73	eval-mae:1139.46
# [714]	train-mae:1018.57	eval-mae:1139.38
# [715]	train-mae:1018.53	eval-mae:1139.41
# [716]	train-mae:1018.38	eval-mae:1139.42
# [717]	train-mae:1018.29	eval-mae:1139.42
# [718]	train-mae:1018.24	eval-mae:1139.35
# [719]	train-mae:1018.01	eval-mae:1139.36
# [720]	train-mae:1017.92	eval-mae:1139.41
# [721]	train-mae:1017.81	eval-mae:1139.48
# [722]	train-mae:1017.7	eval-mae:1139.47
# [723]	train-mae:1017.6	eval-mae:1139.51
# [724]	train-mae:1017.54	eval-mae:1139.59
# [725]	train-mae:1017.48	eval-mae:1139.61
# [726]	train-mae:1017.4	eval-mae:1139.6
# [727]	train-mae:1017.33	eval-mae:1139.6
# [728]	train-mae:1017.2	eval-mae:1139.59
# [729]	train-mae:1017.04	eval-mae:1139.67
# [730]	train-mae:1016.97	eval-mae:1139.66
# [731]	train-mae:1016.88	eval-mae:1139.65
# [732]	train-mae:1016.82	eval-mae:1139.68
# [733]	train-mae:1016.64	eval-mae:1139.78
# [734]	train-mae:1016.46	eval-mae:1139.76
# [735]	train-mae:1016.24	eval-mae:1139.73
# [736]	train-mae:1016.11	eval-mae:1139.73
# [737]	train-mae:1015.95	eval-mae:1139.66
# [738]	train-mae:1015.84	eval-mae:1139.58
# [739]	train-mae:1015.81	eval-mae:1139.55
# [740]	train-mae:1015.78	eval-mae:1139.54
# [741]	train-mae:1015.55	eval-mae:1139.59
# [742]	train-mae:1015.45	eval-mae:1139.61
# [743]	train-mae:1015.36	eval-mae:1139.56
# [744]	train-mae:1015.25	eval-mae:1139.52
# [745]	train-mae:1015.15	eval-mae:1139.47
# [746]	train-mae:1015.06	eval-mae:1139.45
# [747]	train-mae:1014.86	eval-mae:1139.51
# [748]	train-mae:1014.73	eval-mae:1139.5
# [749]	train-mae:1014.66	eval-mae:1139.43
# [750]	train-mae:1014.59	eval-mae:1139.43
# [751]	train-mae:1014.56	eval-mae:1139.47
# [752]	train-mae:1014.42	eval-mae:1139.45
# [753]	train-mae:1014.29	eval-mae:1139.38
# [754]	train-mae:1014.17	eval-mae:1139.36
# [755]	train-mae:1014.07	eval-mae:1139.35
# [756]	train-mae:1013.97	eval-mae:1139.39
# [757]	train-mae:1013.87	eval-mae:1139.38
# [758]	train-mae:1013.7	eval-mae:1139.43
# [759]	train-mae:1013.6	eval-mae:1139.4
# [760]	train-mae:1013.52	eval-mae:1139.36
# [761]	train-mae:1013.42	eval-mae:1139.34
# [762]	train-mae:1013.38	eval-mae:1139.36
# [763]	train-mae:1013.3	eval-mae:1139.41
# [764]	train-mae:1013.19	eval-mae:1139.41
# [765]	train-mae:1013.13	eval-mae:1139.42
# [766]	train-mae:1013.01	eval-mae:1139.41
# [767]	train-mae:1012.87	eval-mae:1139.36
# [768]	train-mae:1012.82	eval-mae:1139.35
# [769]	train-mae:1012.7	eval-mae:1139.35
# [770]	train-mae:1012.58	eval-mae:1139.33
# [771]	train-mae:1012.48	eval-mae:1139.36
# [772]	train-mae:1012.38	eval-mae:1139.34
# [773]	train-mae:1012.2	eval-mae:1139.31
# [774]	train-mae:1012.13	eval-mae:1139.29
# [775]	train-mae:1012.12	eval-mae:1139.29
# [776]	train-mae:1012.03	eval-mae:1139.25
# [777]	train-mae:1011.9	eval-mae:1139.16
# [778]	train-mae:1011.75	eval-mae:1139.16
# [779]	train-mae:1011.51	eval-mae:1139.3
# [780]	train-mae:1011.39	eval-mae:1139.28
# [781]	train-mae:1011.24	eval-mae:1139.35
# [782]	train-mae:1011.12	eval-mae:1139.41
# [783]	train-mae:1010.97	eval-mae:1139.38
# [784]	train-mae:1010.9	eval-mae:1139.33
# [785]	train-mae:1010.71	eval-mae:1139.4
# [786]	train-mae:1010.62	eval-mae:1139.42
# [787]	train-mae:1010.57	eval-mae:1139.41
# [788]	train-mae:1010.5	eval-mae:1139.42
# [789]	train-mae:1010.45	eval-mae:1139.4
# [790]	train-mae:1010.33	eval-mae:1139.35
# [791]	train-mae:1010.23	eval-mae:1139.39
# [792]	train-mae:1010.1	eval-mae:1139.38
# [793]	train-mae:1009.91	eval-mae:1139.32
# [794]	train-mae:1009.73	eval-mae:1139.37
# [795]	train-mae:1009.62	eval-mae:1139.3
# [796]	train-mae:1009.4	eval-mae:1139.37
# [797]	train-mae:1009.3	eval-mae:1139.42
# [798]	train-mae:1009.24	eval-mae:1139.45
# [799]	train-mae:1009.15	eval-mae:1139.46
# [800]	train-mae:1009.06	eval-mae:1139.49
# [801]	train-mae:1008.96	eval-mae:1139.47
# [802]	train-mae:1008.86	eval-mae:1139.53
# [803]	train-mae:1008.78	eval-mae:1139.51
# [804]	train-mae:1008.7	eval-mae:1139.43
# [805]	train-mae:1008.55	eval-mae:1139.4
# [806]	train-mae:1008.46	eval-mae:1139.37
# [807]	train-mae:1008.37	eval-mae:1139.39
# [808]	train-mae:1008.25	eval-mae:1139.36
# [809]	train-mae:1008.09	eval-mae:1139.3
# [810]	train-mae:1008.02	eval-mae:1139.27
# [811]	train-mae:1007.93	eval-mae:1139.24
# [812]	train-mae:1007.83	eval-mae:1139.26
# [813]	train-mae:1007.71	eval-mae:1139.27
# [814]	train-mae:1007.65	eval-mae:1139.29
# [815]	train-mae:1007.45	eval-mae:1139.29
# [816]	train-mae:1007.34	eval-mae:1139.32
# [817]	train-mae:1007.27	eval-mae:1139.36
# [818]	train-mae:1007.12	eval-mae:1139.39
# [819]	train-mae:1006.93	eval-mae:1139.27
# [820]	train-mae:1006.84	eval-mae:1139.25
# [821]	train-mae:1006.74	eval-mae:1139.27
# [822]	train-mae:1006.62	eval-mae:1139.29
# [823]	train-mae:1006.46	eval-mae:1139.31
# [824]	train-mae:1006.34	eval-mae:1139.26
# [825]	train-mae:1006.18	eval-mae:1139.26
# [826]	train-mae:1006.09	eval-mae:1139.26
# [827]	train-mae:1006	eval-mae:1139.26
# [828]	train-mae:1005.84	eval-mae:1139.27
# Stopping. Best iteration:
# [778]	train-mae:1011.75	eval-mae:1139.16
#
# eval-MAE: 1139.161864
#
#  Fold 2
# [0]	train-mae:3218.07	eval-mae:3196.64
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 50 rounds.
# [1]	train-mae:3175.98	eval-mae:3154.56
# [2]	train-mae:3114.84	eval-mae:3093.35
# [3]	train-mae:3041.06	eval-mae:3019.41
# [4]	train-mae:2960.85	eval-mae:2939.01
# [5]	train-mae:2877.92	eval-mae:2855.7
# [6]	train-mae:2795	eval-mae:2772.45
# [7]	train-mae:2714.53	eval-mae:2691.57
# [8]	train-mae:2636.18	eval-mae:2612.9
# [9]	train-mae:2560.76	eval-mae:2537.14
# [10]	train-mae:2488.56	eval-mae:2464.51
# [11]	train-mae:2419.58	eval-mae:2395.21
# [12]	train-mae:2353.81	eval-mae:2329.07
# [13]	train-mae:2291.73	eval-mae:2266.98
# [14]	train-mae:2233.03	eval-mae:2208.46
# [15]	train-mae:2177.29	eval-mae:2152.93
# [16]	train-mae:2124.58	eval-mae:2100.2
# [17]	train-mae:2074.83	eval-mae:2050.58
# [18]	train-mae:2027.66	eval-mae:2003.67
# [19]	train-mae:1982.87	eval-mae:1959.17
# [20]	train-mae:1940.3	eval-mae:1916.85
# [21]	train-mae:1899.98	eval-mae:1876.91
# [22]	train-mae:1861.49	eval-mae:1838.96
# [23]	train-mae:1824.89	eval-mae:1802.95
# [24]	train-mae:1790.19	eval-mae:1769.13
# [25]	train-mae:1757.15	eval-mae:1736.71
# [26]	train-mae:1726.21	eval-mae:1706.19
# [27]	train-mae:1696.64	eval-mae:1677.05
# [28]	train-mae:1668.51	eval-mae:1649.58
# [29]	train-mae:1642.07	eval-mae:1623.81
# [30]	train-mae:1616.85	eval-mae:1599.12
# [31]	train-mae:1592.95	eval-mae:1575.99
# [32]	train-mae:1570.17	eval-mae:1553.96
# [33]	train-mae:1548.51	eval-mae:1533.12
# [34]	train-mae:1527.88	eval-mae:1513.02
# [35]	train-mae:1508.36	eval-mae:1494.36
# [36]	train-mae:1489.76	eval-mae:1476.68
# [37]	train-mae:1471.98	eval-mae:1459.91
# [38]	train-mae:1455.01	eval-mae:1443.96
# [39]	train-mae:1439.16	eval-mae:1429.23
# [40]	train-mae:1423.95	eval-mae:1415.01
# [41]	train-mae:1409.44	eval-mae:1401.45
# [42]	train-mae:1395.7	eval-mae:1388.73
# [43]	train-mae:1382.45	eval-mae:1376.35
# [44]	train-mae:1370.08	eval-mae:1364.81
# [45]	train-mae:1358.34	eval-mae:1353.82
# [46]	train-mae:1347.02	eval-mae:1343.51
# [47]	train-mae:1336.42	eval-mae:1333.83
# [48]	train-mae:1326.17	eval-mae:1324.56
# [49]	train-mae:1316.48	eval-mae:1315.94
# [50]	train-mae:1307.44	eval-mae:1307.75
# [51]	train-mae:1298.72	eval-mae:1299.85
# [52]	train-mae:1290.44	eval-mae:1292.49
# [53]	train-mae:1282.55	eval-mae:1285.5
# [54]	train-mae:1275.1	eval-mae:1279
# [55]	train-mae:1268	eval-mae:1272.84
# [56]	train-mae:1261.25	eval-mae:1267.11
# [57]	train-mae:1254.73	eval-mae:1261.65
# [58]	train-mae:1248.71	eval-mae:1256.44
# [59]	train-mae:1243.01	eval-mae:1251.49
# [60]	train-mae:1237.55	eval-mae:1246.86
# [61]	train-mae:1232.31	eval-mae:1242.48
# [62]	train-mae:1227.31	eval-mae:1238.42
# [63]	train-mae:1222.26	eval-mae:1234.37
# [64]	train-mae:1217.69	eval-mae:1230.61
# [65]	train-mae:1213.3	eval-mae:1227.08
# [66]	train-mae:1208.97	eval-mae:1223.66
# [67]	train-mae:1205.09	eval-mae:1220.58
# [68]	train-mae:1201.37	eval-mae:1217.59
# [69]	train-mae:1197.66	eval-mae:1214.72
# [70]	train-mae:1194.07	eval-mae:1212.05
# [71]	train-mae:1190.68	eval-mae:1209.54
# [72]	train-mae:1187.61	eval-mae:1207.25
# [73]	train-mae:1184.49	eval-mae:1204.76
# [74]	train-mae:1181.69	eval-mae:1202.8
# [75]	train-mae:1178.8	eval-mae:1200.7
# [76]	train-mae:1176.24	eval-mae:1198.69
# [77]	train-mae:1173.89	eval-mae:1196.97
# [78]	train-mae:1171.39	eval-mae:1194.96
# [79]	train-mae:1169.06	eval-mae:1193.24
# [80]	train-mae:1167.11	eval-mae:1191.74
# [81]	train-mae:1165.13	eval-mae:1190.24
# [82]	train-mae:1163.34	eval-mae:1188.79
# [83]	train-mae:1161.47	eval-mae:1187.33
# [84]	train-mae:1159.68	eval-mae:1186.1
# [85]	train-mae:1157.96	eval-mae:1184.86
# [86]	train-mae:1156.35	eval-mae:1183.76
# [87]	train-mae:1154.77	eval-mae:1182.62
# [88]	train-mae:1153.06	eval-mae:1181.41
# [89]	train-mae:1151.5	eval-mae:1180.28
# [90]	train-mae:1150.24	eval-mae:1179.27
# [91]	train-mae:1148.74	eval-mae:1178.31
# [92]	train-mae:1147.46	eval-mae:1177.53
# [93]	train-mae:1146.09	eval-mae:1176.7
# [94]	train-mae:1144.81	eval-mae:1175.94
# [95]	train-mae:1143.77	eval-mae:1175.19
# [96]	train-mae:1142.79	eval-mae:1174.54
# [97]	train-mae:1141.65	eval-mae:1173.82
# [98]	train-mae:1140.61	eval-mae:1173.12
# [99]	train-mae:1139.67	eval-mae:1172.39
# [100]	train-mae:1138.72	eval-mae:1171.73
# [101]	train-mae:1137.79	eval-mae:1171.17
# [102]	train-mae:1136.95	eval-mae:1170.68
# [103]	train-mae:1136.05	eval-mae:1170.2
# [104]	train-mae:1135.37	eval-mae:1169.69
# [105]	train-mae:1134.57	eval-mae:1169.13
# [106]	train-mae:1133.91	eval-mae:1168.78
# [107]	train-mae:1133.06	eval-mae:1168.39
# [108]	train-mae:1132.38	eval-mae:1167.94
# [109]	train-mae:1131.3	eval-mae:1167.39
# [110]	train-mae:1130.6	eval-mae:1167.02
# [111]	train-mae:1129.9	eval-mae:1166.71
# [112]	train-mae:1129.08	eval-mae:1166.35
# [113]	train-mae:1128.46	eval-mae:1165.98
# [114]	train-mae:1127.67	eval-mae:1165.67
# [115]	train-mae:1127.2	eval-mae:1165.38
# [116]	train-mae:1126.59	eval-mae:1165.03
# [117]	train-mae:1125.72	eval-mae:1164.46
# [118]	train-mae:1125.09	eval-mae:1164.04
# [119]	train-mae:1124.26	eval-mae:1163.63
# [120]	train-mae:1123.82	eval-mae:1163.4
# [121]	train-mae:1123.42	eval-mae:1163.14
# [122]	train-mae:1122.88	eval-mae:1162.86
# [123]	train-mae:1122.47	eval-mae:1162.74
# [124]	train-mae:1121.89	eval-mae:1162.51
# [125]	train-mae:1121.53	eval-mae:1162.31
# [126]	train-mae:1120.94	eval-mae:1161.98
# [127]	train-mae:1120.4	eval-mae:1161.81
# [128]	train-mae:1120.04	eval-mae:1161.54
# [129]	train-mae:1119.66	eval-mae:1161.4
# [130]	train-mae:1119.19	eval-mae:1161.17
# [131]	train-mae:1118.85	eval-mae:1160.97
# [132]	train-mae:1118.38	eval-mae:1160.75
# [133]	train-mae:1117.81	eval-mae:1160.43
# [134]	train-mae:1117.41	eval-mae:1160.28
# [135]	train-mae:1117.11	eval-mae:1160.15
# [136]	train-mae:1116.68	eval-mae:1159.89
# [137]	train-mae:1116.22	eval-mae:1159.77
# [138]	train-mae:1115.73	eval-mae:1159.53
# [139]	train-mae:1115.09	eval-mae:1159.33
# [140]	train-mae:1114.8	eval-mae:1159.26
# [141]	train-mae:1114.5	eval-mae:1159.15
# [142]	train-mae:1113.93	eval-mae:1158.84
# [143]	train-mae:1113.65	eval-mae:1158.82
# [144]	train-mae:1113.28	eval-mae:1158.7
# [145]	train-mae:1112.72	eval-mae:1158.37
# [146]	train-mae:1112.26	eval-mae:1158.24
# [147]	train-mae:1112.03	eval-mae:1158.09
# [148]	train-mae:1111.57	eval-mae:1157.86
# [149]	train-mae:1111.27	eval-mae:1157.79
# [150]	train-mae:1110.74	eval-mae:1157.55
# [151]	train-mae:1110.17	eval-mae:1157.54
# [152]	train-mae:1109.89	eval-mae:1157.41
# [153]	train-mae:1109.53	eval-mae:1157.26
# [154]	train-mae:1109.3	eval-mae:1157.2
# [155]	train-mae:1108.8	eval-mae:1156.77
# [156]	train-mae:1108.42	eval-mae:1156.64
# [157]	train-mae:1107.86	eval-mae:1156.38
# [158]	train-mae:1107.44	eval-mae:1156.14
# [159]	train-mae:1107.13	eval-mae:1155.99
# [160]	train-mae:1106.97	eval-mae:1155.9
# [161]	train-mae:1106.56	eval-mae:1155.61
# [162]	train-mae:1106.3	eval-mae:1155.52
# [163]	train-mae:1105.94	eval-mae:1155.54
# [164]	train-mae:1105.75	eval-mae:1155.54
# [165]	train-mae:1105.57	eval-mae:1155.47
# [166]	train-mae:1105.4	eval-mae:1155.4
# [167]	train-mae:1104.95	eval-mae:1155.28
# [168]	train-mae:1104.74	eval-mae:1155.16
# [169]	train-mae:1104.46	eval-mae:1154.98
# [170]	train-mae:1104.12	eval-mae:1154.94
# [171]	train-mae:1103.75	eval-mae:1154.84
# [172]	train-mae:1103.53	eval-mae:1154.76
# [173]	train-mae:1102.96	eval-mae:1154.36
# [174]	train-mae:1102.52	eval-mae:1154.25
# [175]	train-mae:1102.22	eval-mae:1154.09
# [176]	train-mae:1102.07	eval-mae:1153.96
# [177]	train-mae:1101.63	eval-mae:1153.84
# [178]	train-mae:1101.2	eval-mae:1153.67
# [179]	train-mae:1100.93	eval-mae:1153.54
# [180]	train-mae:1100.51	eval-mae:1153.41
# [181]	train-mae:1100.4	eval-mae:1153.37
# [182]	train-mae:1100.21	eval-mae:1153.26
# [183]	train-mae:1100.07	eval-mae:1153.2
# [184]	train-mae:1099.93	eval-mae:1153.15
# [185]	train-mae:1099.54	eval-mae:1152.93
# [186]	train-mae:1099.13	eval-mae:1152.84
# [187]	train-mae:1098.73	eval-mae:1152.74
# [188]	train-mae:1098.24	eval-mae:1152.67
# [189]	train-mae:1097.96	eval-mae:1152.48
# [190]	train-mae:1097.58	eval-mae:1152.3
# [191]	train-mae:1097.42	eval-mae:1152.31
# [192]	train-mae:1097.28	eval-mae:1152.26
# [193]	train-mae:1097.15	eval-mae:1152.17
# [194]	train-mae:1096.94	eval-mae:1152.03
# [195]	train-mae:1096.81	eval-mae:1152.04
# [196]	train-mae:1096.4	eval-mae:1151.9
# [197]	train-mae:1096.28	eval-mae:1151.87
# [198]	train-mae:1095.97	eval-mae:1151.83
# [199]	train-mae:1095.68	eval-mae:1151.67
# [200]	train-mae:1095.54	eval-mae:1151.5
# [201]	train-mae:1095.4	eval-mae:1151.43
# [202]	train-mae:1095.25	eval-mae:1151.33
# [203]	train-mae:1094.9	eval-mae:1151.12
# [204]	train-mae:1094.73	eval-mae:1151.1
# [205]	train-mae:1094.64	eval-mae:1151.14
# [206]	train-mae:1094.38	eval-mae:1151.09
# [207]	train-mae:1094.2	eval-mae:1150.98
# [208]	train-mae:1093.95	eval-mae:1150.78
# [209]	train-mae:1093.78	eval-mae:1150.71
# [210]	train-mae:1093.32	eval-mae:1150.71
# [211]	train-mae:1093.11	eval-mae:1150.58
# [212]	train-mae:1092.93	eval-mae:1150.54
# [213]	train-mae:1092.76	eval-mae:1150.53
# [214]	train-mae:1092.66	eval-mae:1150.45
# [215]	train-mae:1092.52	eval-mae:1150.37
# [216]	train-mae:1092.43	eval-mae:1150.39
# [217]	train-mae:1092.21	eval-mae:1150.28
# [218]	train-mae:1091.86	eval-mae:1150.14
# [219]	train-mae:1091.65	eval-mae:1150.17
# [220]	train-mae:1091.28	eval-mae:1150.08
# [221]	train-mae:1091.1	eval-mae:1150.01
# [222]	train-mae:1090.85	eval-mae:1149.94
# [223]	train-mae:1090.7	eval-mae:1149.83
# [224]	train-mae:1090.53	eval-mae:1149.74
# [225]	train-mae:1090.09	eval-mae:1149.62
# [226]	train-mae:1089.73	eval-mae:1149.58
# [227]	train-mae:1089.44	eval-mae:1149.52
# [228]	train-mae:1089.14	eval-mae:1149.36
# [229]	train-mae:1088.99	eval-mae:1149.43
# [230]	train-mae:1088.75	eval-mae:1149.34
# [231]	train-mae:1088.46	eval-mae:1149.18
# [232]	train-mae:1088.3	eval-mae:1149.12
# [233]	train-mae:1088.09	eval-mae:1149.04
# [234]	train-mae:1087.78	eval-mae:1148.94
# [235]	train-mae:1087.48	eval-mae:1148.84
# [236]	train-mae:1087.33	eval-mae:1148.74
# [237]	train-mae:1087.12	eval-mae:1148.8
# [238]	train-mae:1086.78	eval-mae:1148.67
# [239]	train-mae:1086.35	eval-mae:1148.58
# [240]	train-mae:1086.19	eval-mae:1148.51
# [241]	train-mae:1086.01	eval-mae:1148.41
# [242]	train-mae:1085.76	eval-mae:1148.2
# [243]	train-mae:1085.54	eval-mae:1148.02
# [244]	train-mae:1085.4	eval-mae:1147.98
# [245]	train-mae:1085.35	eval-mae:1147.96
# [246]	train-mae:1085.17	eval-mae:1147.83
# [247]	train-mae:1085	eval-mae:1147.89
# [248]	train-mae:1084.85	eval-mae:1147.9
# [249]	train-mae:1084.59	eval-mae:1147.71
# [250]	train-mae:1084.25	eval-mae:1147.48
# [251]	train-mae:1083.96	eval-mae:1147.32
# [252]	train-mae:1083.75	eval-mae:1147.26
# [253]	train-mae:1083.45	eval-mae:1147.26
# [254]	train-mae:1083.34	eval-mae:1147.24
# [255]	train-mae:1083.15	eval-mae:1147.18
# [256]	train-mae:1082.76	eval-mae:1147.14
# [257]	train-mae:1082.58	eval-mae:1147.07
# [258]	train-mae:1082.44	eval-mae:1147
# [259]	train-mae:1082.27	eval-mae:1147
# [260]	train-mae:1082.15	eval-mae:1147.04
# [261]	train-mae:1082.02	eval-mae:1147.08
# [262]	train-mae:1081.66	eval-mae:1146.74
# [263]	train-mae:1081.52	eval-mae:1146.67
# [264]	train-mae:1081.24	eval-mae:1146.52
# [265]	train-mae:1080.9	eval-mae:1146.35
# [266]	train-mae:1080.73	eval-mae:1146.26
# [267]	train-mae:1080.59	eval-mae:1146.26
# [268]	train-mae:1080.37	eval-mae:1146.15
# [269]	train-mae:1080.25	eval-mae:1146.08
# [270]	train-mae:1080.02	eval-mae:1146
# [271]	train-mae:1079.7	eval-mae:1145.89
# [272]	train-mae:1079.57	eval-mae:1145.84
# [273]	train-mae:1079.13	eval-mae:1145.63
# [274]	train-mae:1078.97	eval-mae:1145.51
# [275]	train-mae:1078.8	eval-mae:1145.48
# [276]	train-mae:1078.73	eval-mae:1145.46
# [277]	train-mae:1078.5	eval-mae:1145.42
# [278]	train-mae:1078.29	eval-mae:1145.31
# [279]	train-mae:1078.08	eval-mae:1145.26
# [280]	train-mae:1077.81	eval-mae:1145.1
# [281]	train-mae:1077.62	eval-mae:1144.97
# [282]	train-mae:1077.47	eval-mae:1144.85
# [283]	train-mae:1077.17	eval-mae:1144.74
# [284]	train-mae:1077.04	eval-mae:1144.71
# [285]	train-mae:1076.87	eval-mae:1144.56
# [286]	train-mae:1076.44	eval-mae:1144.33
# [287]	train-mae:1076.36	eval-mae:1144.24
# [288]	train-mae:1076.06	eval-mae:1144.25
# [289]	train-mae:1075.95	eval-mae:1144.28
# [290]	train-mae:1075.78	eval-mae:1144.24
# [291]	train-mae:1075.57	eval-mae:1144.26
# [292]	train-mae:1075.38	eval-mae:1144.27
# [293]	train-mae:1075.15	eval-mae:1144.2
# [294]	train-mae:1075.05	eval-mae:1144.16
# [295]	train-mae:1074.83	eval-mae:1144.17
# [296]	train-mae:1074.61	eval-mae:1144.13
# [297]	train-mae:1074.52	eval-mae:1144.12
# [298]	train-mae:1074.32	eval-mae:1144.04
# [299]	train-mae:1074.1	eval-mae:1143.87
# [300]	train-mae:1073.99	eval-mae:1143.85
# [301]	train-mae:1073.82	eval-mae:1143.82
# [302]	train-mae:1073.64	eval-mae:1143.77
# [303]	train-mae:1073.4	eval-mae:1143.73
# [304]	train-mae:1073.32	eval-mae:1143.71
# [305]	train-mae:1073.14	eval-mae:1143.61
# [306]	train-mae:1072.95	eval-mae:1143.73
# [307]	train-mae:1072.87	eval-mae:1143.74
# [308]	train-mae:1072.74	eval-mae:1143.69
# [309]	train-mae:1072.52	eval-mae:1143.6
# [310]	train-mae:1072.2	eval-mae:1143.65
# [311]	train-mae:1072	eval-mae:1143.58
# [312]	train-mae:1071.82	eval-mae:1143.52
# [313]	train-mae:1071.64	eval-mae:1143.4
# [314]	train-mae:1071.36	eval-mae:1143.29
# [315]	train-mae:1071.26	eval-mae:1143.31
# [316]	train-mae:1070.98	eval-mae:1143.21
# [317]	train-mae:1070.84	eval-mae:1143.22
# [318]	train-mae:1070.66	eval-mae:1143.19
# [319]	train-mae:1070.55	eval-mae:1143.2
# [320]	train-mae:1070.39	eval-mae:1143.16
# [321]	train-mae:1070.09	eval-mae:1143.17
# [322]	train-mae:1069.95	eval-mae:1143.05
# [323]	train-mae:1069.73	eval-mae:1142.97
# [324]	train-mae:1069.42	eval-mae:1142.81
# [325]	train-mae:1069.3	eval-mae:1142.83
# [326]	train-mae:1069.17	eval-mae:1142.84
# [327]	train-mae:1069.07	eval-mae:1142.8
# [328]	train-mae:1068.93	eval-mae:1142.8
# [329]	train-mae:1068.77	eval-mae:1142.84
# [330]	train-mae:1068.59	eval-mae:1142.76
# [331]	train-mae:1068.49	eval-mae:1142.7
# [332]	train-mae:1068.33	eval-mae:1142.78
# [333]	train-mae:1068.25	eval-mae:1142.79
# [334]	train-mae:1068.1	eval-mae:1142.73
# [335]	train-mae:1067.84	eval-mae:1142.68
# [336]	train-mae:1067.6	eval-mae:1142.56
# [337]	train-mae:1067.45	eval-mae:1142.49
# [338]	train-mae:1067.26	eval-mae:1142.37
# [339]	train-mae:1067.22	eval-mae:1142.33
# [340]	train-mae:1067.13	eval-mae:1142.37
# [341]	train-mae:1066.92	eval-mae:1142.32
# [342]	train-mae:1066.81	eval-mae:1142.27
# [343]	train-mae:1066.66	eval-mae:1142.26
# ...
# [349]	train-mae:1064.41	eval-mae:1160.02
# [350]	train-mae:1064.3	eval-mae:1159.93
# [351]	train-mae:1064.16	eval-mae:1159.89
# [352]	train-mae:1064.01	eval-mae:1159.77
# [353]	train-mae:1063.75	eval-mae:1159.64
# [354]	train-mae:1063.55	eval-mae:1159.63
# [355]	train-mae:1063.46	eval-mae:1159.65
# [356]	train-mae:1063.25	eval-mae:1159.57
# [357]	train-mae:1063.05	eval-mae:1159.63
# [358]	train-mae:1062.97	eval-mae:1159.57
# [359]	train-mae:1062.84	eval-mae:1159.56
# [360]	train-mae:1062.66	eval-mae:1159.56
# [361]	train-mae:1062.58	eval-mae:1159.57
# [362]	train-mae:1062.48	eval-mae:1159.59
# [363]	train-mae:1062.19	eval-mae:1159.46
# [364]	train-mae:1062.01	eval-mae:1159.46
# [365]	train-mae:1061.91	eval-mae:1159.48
# [366]	train-mae:1061.71	eval-mae:1159.55
# [367]	train-mae:1061.6	eval-mae:1159.52
# [368]	train-mae:1061.29	eval-mae:1159.61
# [369]	train-mae:1061.12	eval-mae:1159.62
# [370]	train-mae:1061.05	eval-mae:1159.54
# [371]	train-mae:1060.93	eval-mae:1159.56
# [372]	train-mae:1060.67	eval-mae:1159.6
# [373]	train-mae:1060.54	eval-mae:1159.53
# [374]	train-mae:1060.48	eval-mae:1159.52
# [375]	train-mae:1060.38	eval-mae:1159.53
# [376]	train-mae:1060.17	eval-mae:1159.48
# [377]	train-mae:1060.12	eval-mae:1159.45
# [378]	train-mae:1059.84	eval-mae:1159.41
# [379]	train-mae:1059.7	eval-mae:1159.38
# [380]	train-mae:1059.59	eval-mae:1159.36
# [381]	train-mae:1059.44	eval-mae:1159.33
# [382]	train-mae:1059.18	eval-mae:1159.34
# [383]	train-mae:1059.12	eval-mae:1159.3
# [384]	train-mae:1058.9	eval-mae:1159.29
# [385]	train-mae:1058.7	eval-mae:1159.33
# [386]	train-mae:1058.59	eval-mae:1159.26
# [387]	train-mae:1058.47	eval-mae:1159.2
# [388]	train-mae:1058.25	eval-mae:1159.15
# [389]	train-mae:1058.13	eval-mae:1159.16
# [390]	train-mae:1058.06	eval-mae:1159.08
# [391]	train-mae:1057.84	eval-mae:1159.08
# [392]	train-mae:1057.57	eval-mae:1159
# [393]	train-mae:1057.39	eval-mae:1159.05
# [394]	train-mae:1057.2	eval-mae:1158.97
# [395]	train-mae:1057.08	eval-mae:1158.86
# [396]	train-mae:1056.95	eval-mae:1158.83
# [397]	train-mae:1056.73	eval-mae:1158.72
# [398]	train-mae:1056.68	eval-mae:1158.71
# [399]	train-mae:1056.57	eval-mae:1158.69
# [400]	train-mae:1056.46	eval-mae:1158.62
# [401]	train-mae:1056.32	eval-mae:1158.63
# [402]	train-mae:1056.15	eval-mae:1158.59
# [403]	train-mae:1055.96	eval-mae:1158.53
# [404]	train-mae:1055.79	eval-mae:1158.58
# [405]	train-mae:1055.6	eval-mae:1158.59
# [406]	train-mae:1055.5	eval-mae:1158.52
# [407]	train-mae:1055.43	eval-mae:1158.52
# [408]	train-mae:1055.3	eval-mae:1158.53
# [409]	train-mae:1055.25	eval-mae:1158.53
# [410]	train-mae:1055.04	eval-mae:1158.51
# [411]	train-mae:1054.97	eval-mae:1158.5
# [412]	train-mae:1054.81	eval-mae:1158.51
# [413]	train-mae:1054.58	eval-mae:1158.43
# [414]	train-mae:1054.52	eval-mae:1158.42
# [415]	train-mae:1054.34	eval-mae:1158.42
# [416]	train-mae:1054.22	eval-mae:1158.41
# [417]	train-mae:1054.07	eval-mae:1158.46
# [418]	train-mae:1053.93	eval-mae:1158.5
# [419]	train-mae:1053.81	eval-mae:1158.49
# [420]	train-mae:1053.62	eval-mae:1158.49
# [421]	train-mae:1053.49	eval-mae:1158.44
# [422]	train-mae:1053.4	eval-mae:1158.35
# [423]	train-mae:1053.27	eval-mae:1158.34
# [424]	train-mae:1053.09	eval-mae:1158.34
# [425]	train-mae:1052.97	eval-mae:1158.29
# [426]	train-mae:1052.84	eval-mae:1158.28
# [427]	train-mae:1052.72	eval-mae:1158.24
# [428]	train-mae:1052.58	eval-mae:1158.29
# [429]	train-mae:1052.34	eval-mae:1158.29
# [430]	train-mae:1052.13	eval-mae:1158.2
# [431]	train-mae:1051.98	eval-mae:1158.18
# [432]	train-mae:1051.89	eval-mae:1158.18
# [433]	train-mae:1051.83	eval-mae:1158.21
# [434]	train-mae:1051.5	eval-mae:1158.18
# [435]	train-mae:1051.34	eval-mae:1158.29
# [436]	train-mae:1051.18	eval-mae:1158.24
# [437]	train-mae:1051.12	eval-mae:1158.29
# [438]	train-mae:1050.98	eval-mae:1158.27
# [439]	train-mae:1050.9	eval-mae:1158.24
# [440]	train-mae:1050.76	eval-mae:1158.24
# [441]	train-mae:1050.55	eval-mae:1158.25
# [442]	train-mae:1050.46	eval-mae:1158.27
# [443]	train-mae:1050.42	eval-mae:1158.28
# [444]	train-mae:1050.36	eval-mae:1158.26
# [445]	train-mae:1050.08	eval-mae:1158.18
# [446]	train-mae:1049.89	eval-mae:1158.15
# [447]	train-mae:1049.79	eval-mae:1158.1
# [448]	train-mae:1049.67	eval-mae:1158.09
# [449]	train-mae:1049.49	eval-mae:1158.15
# [450]	train-mae:1049.38	eval-mae:1158.18
# [451]	train-mae:1049.2	eval-mae:1158.13
# [452]	train-mae:1049.04	eval-mae:1158.12
# [453]	train-mae:1048.82	eval-mae:1158.17
# [454]	train-mae:1048.64	eval-mae:1158.1
# [455]	train-mae:1048.45	eval-mae:1158.13
# [456]	train-mae:1048.25	eval-mae:1158.11
# [457]	train-mae:1048.13	eval-mae:1158.06
# [458]	train-mae:1047.93	eval-mae:1158.02
# [459]	train-mae:1047.86	eval-mae:1158.03
# [460]	train-mae:1047.75	eval-mae:1157.99
# [461]	train-mae:1047.69	eval-mae:1157.92
# [462]	train-mae:1047.64	eval-mae:1157.94
# [463]	train-mae:1047.54	eval-mae:1157.91
# [464]	train-mae:1047.5	eval-mae:1157.91
# [465]	train-mae:1047.38	eval-mae:1157.88
# [466]	train-mae:1047.21	eval-mae:1157.85
# [467]	train-mae:1047.1	eval-mae:1157.81
# [468]	train-mae:1046.86	eval-mae:1157.92
# [469]	train-mae:1046.79	eval-mae:1157.9
# [470]	train-mae:1046.65	eval-mae:1157.87
# [471]	train-mae:1046.55	eval-mae:1157.81
# [472]	train-mae:1046.46	eval-mae:1157.81
# [473]	train-mae:1046.31	eval-mae:1157.75
# [474]	train-mae:1046.11	eval-mae:1157.65
# [475]	train-mae:1045.94	eval-mae:1157.61
# [476]	train-mae:1045.77	eval-mae:1157.56
# [477]	train-mae:1045.51	eval-mae:1157.57
# [478]	train-mae:1045.34	eval-mae:1157.53
# [479]	train-mae:1045.19	eval-mae:1157.44
# [480]	train-mae:1045.11	eval-mae:1157.42
# [481]	train-mae:1045.04	eval-mae:1157.4
# [482]	train-mae:1044.87	eval-mae:1157.41
# [483]	train-mae:1044.69	eval-mae:1157.37
# [484]	train-mae:1044.6	eval-mae:1157.39
# [485]	train-mae:1044.48	eval-mae:1157.38
# [486]	train-mae:1044.41	eval-mae:1157.33
# [487]	train-mae:1044.33	eval-mae:1157.16
# [488]	train-mae:1044.16	eval-mae:1157.19
# [489]	train-mae:1044.06	eval-mae:1157.14
# [490]	train-mae:1043.96	eval-mae:1157.09
# [491]	train-mae:1043.83	eval-mae:1157.09
# [492]	train-mae:1043.66	eval-mae:1157.15
# [493]	train-mae:1043.57	eval-mae:1157.16
# [494]	train-mae:1043.42	eval-mae:1157.08
# [495]	train-mae:1043.36	eval-mae:1157.05
# [496]	train-mae:1043.05	eval-mae:1157.14
# [497]	train-mae:1042.99	eval-mae:1157.1
# [498]	train-mae:1042.81	eval-mae:1156.97
# [499]	train-mae:1042.7	eval-mae:1156.9
# [500]	train-mae:1042.58	eval-mae:1156.98
# [501]	train-mae:1042.51	eval-mae:1156.96
# [502]	train-mae:1042.47	eval-mae:1156.98
# [503]	train-mae:1042.28	eval-mae:1156.99
# [504]	train-mae:1042.09	eval-mae:1156.95
# [505]	train-mae:1042.02	eval-mae:1157.02
# [506]	train-mae:1041.89	eval-mae:1156.99
# [507]	train-mae:1041.76	eval-mae:1157.08
# [508]	train-mae:1041.69	eval-mae:1157.1
# [509]	train-mae:1041.59	eval-mae:1157.05
# [510]	train-mae:1041.49	eval-mae:1157.03
# [511]	train-mae:1041.28	eval-mae:1156.91
# [512]	train-mae:1041.05	eval-mae:1156.82
# [513]	train-mae:1040.83	eval-mae:1156.94
# [514]	train-mae:1040.69	eval-mae:1156.98
# [515]	train-mae:1040.59	eval-mae:1156.97
# [516]	train-mae:1040.52	eval-mae:1156.89
# [517]	train-mae:1040.35	eval-mae:1156.88
# [518]	train-mae:1040.21	eval-mae:1156.89
# [519]	train-mae:1040.14	eval-mae:1156.91
# [520]	train-mae:1040.08	eval-mae:1156.89
# [521]	train-mae:1039.91	eval-mae:1156.9
# [522]	train-mae:1039.81	eval-mae:1156.86
# [523]	train-mae:1039.71	eval-mae:1156.9
# [524]	train-mae:1039.56	eval-mae:1157.02
# [525]	train-mae:1039.43	eval-mae:1157.07
# [526]	train-mae:1039.3	eval-mae:1157.05
# [527]	train-mae:1039.23	eval-mae:1156.97
# [528]	train-mae:1039.13	eval-mae:1157.02
# [529]	train-mae:1039.02	eval-mae:1156.97
# [530]	train-mae:1038.89	eval-mae:1157.01
# [531]	train-mae:1038.8	eval-mae:1157.02
# [532]	train-mae:1038.69	eval-mae:1157
# [533]	train-mae:1038.54	eval-mae:1156.89
# [534]	train-mae:1038.51	eval-mae:1156.89
# [535]	train-mae:1038.46	eval-mae:1156.95
# [536]	train-mae:1038.38	eval-mae:1156.92
# [537]	train-mae:1038.25	eval-mae:1156.84
# [538]	train-mae:1038.12	eval-mae:1156.87
# [539]	train-mae:1037.98	eval-mae:1157
# [540]	train-mae:1037.87	eval-mae:1156.93
# [541]	train-mae:1037.78	eval-mae:1156.87
# [542]	train-mae:1037.56	eval-mae:1156.81
# [543]	train-mae:1037.48	eval-mae:1156.79
# [544]	train-mae:1037.45	eval-mae:1156.76
# [545]	train-mae:1037.25	eval-mae:1156.75
# [546]	train-mae:1037.05	eval-mae:1156.8
# [547]	train-mae:1036.91	eval-mae:1156.75
# [548]	train-mae:1036.79	eval-mae:1156.68
# [549]	train-mae:1036.75	eval-mae:1156.7
# [550]	train-mae:1036.63	eval-mae:1156.75
# [551]	train-mae:1036.53	eval-mae:1156.73
# [552]	train-mae:1036.47	eval-mae:1156.7
# [553]	train-mae:1036.29	eval-mae:1156.72
# [554]	train-mae:1036.09	eval-mae:1156.54
# [555]	train-mae:1035.95	eval-mae:1156.53
# [556]	train-mae:1035.78	eval-mae:1156.59
# [557]	train-mae:1035.65	eval-mae:1156.52
# [558]	train-mae:1035.57	eval-mae:1156.55
# [559]	train-mae:1035.52	eval-mae:1156.52
# [560]	train-mae:1035.35	eval-mae:1156.5
# [561]	train-mae:1035.3	eval-mae:1156.48
# [562]	train-mae:1035.19	eval-mae:1156.52
# [563]	train-mae:1035.14	eval-mae:1156.5
# [564]	train-mae:1034.92	eval-mae:1156.47
# [565]	train-mae:1034.76	eval-mae:1156.42
# [566]	train-mae:1034.64	eval-mae:1156.4
# [567]	train-mae:1034.52	eval-mae:1156.35
# [568]	train-mae:1034.31	eval-mae:1156.42
# [569]	train-mae:1034.11	eval-mae:1156.41
# [570]	train-mae:1034.04	eval-mae:1156.39
# [571]	train-mae:1033.93	eval-mae:1156.36
# [572]	train-mae:1033.74	eval-mae:1156.33
# [573]	train-mae:1033.56	eval-mae:1156.32
# [574]	train-mae:1033.38	eval-mae:1156.33
# [575]	train-mae:1033.33	eval-mae:1156.3
# [576]	train-mae:1033.26	eval-mae:1156.22
# [577]	train-mae:1033.15	eval-mae:1156.28
# [578]	train-mae:1033.07	eval-mae:1156.27
# [579]	train-mae:1032.84	eval-mae:1156.15
# [580]	train-mae:1032.78	eval-mae:1156.14
# [581]	train-mae:1032.61	eval-mae:1156.17
# [582]	train-mae:1032.46	eval-mae:1156.13
# [583]	train-mae:1032.41	eval-mae:1156.14
# [584]	train-mae:1032.22	eval-mae:1156.14
# [585]	train-mae:1032.18	eval-mae:1156.12
# [586]	train-mae:1032.06	eval-mae:1156.1
# [587]	train-mae:1031.98	eval-mae:1156.02
# [588]	train-mae:1031.89	eval-mae:1156.03
# [589]	train-mae:1031.79	eval-mae:1156.03
# [590]	train-mae:1031.64	eval-mae:1155.98
# [591]	train-mae:1031.53	eval-mae:1155.97
# [592]	train-mae:1031.38	eval-mae:1155.95
# [593]	train-mae:1031.13	eval-mae:1155.82
# [594]	train-mae:1031.05	eval-mae:1155.82
# [595]	train-mae:1030.9	eval-mae:1155.8
# [596]	train-mae:1030.77	eval-mae:1155.77
# [597]	train-mae:1030.7	eval-mae:1155.8
# [598]	train-mae:1030.63	eval-mae:1155.76
# [599]	train-mae:1030.41	eval-mae:1155.65
# [600]	train-mae:1030.22	eval-mae:1155.67
# [601]	train-mae:1029.98	eval-mae:1155.64
# [602]	train-mae:1029.93	eval-mae:1155.64
# [603]	train-mae:1029.9	eval-mae:1155.65
# [604]	train-mae:1029.78	eval-mae:1155.69
# [605]	train-mae:1029.72	eval-mae:1155.66
# [606]	train-mae:1029.54	eval-mae:1155.66
# [607]	train-mae:1029.37	eval-mae:1155.7
# [608]	train-mae:1029.3	eval-mae:1155.72
# [609]	train-mae:1029.22	eval-mae:1155.7
# [610]	train-mae:1029.12	eval-mae:1155.7
# [611]	train-mae:1029	eval-mae:1155.67
# [612]	train-mae:1028.97	eval-mae:1155.66
# [613]	train-mae:1028.87	eval-mae:1155.69
# [614]	train-mae:1028.65	eval-mae:1155.62
# [615]	train-mae:1028.52	eval-mae:1155.73
# [616]	train-mae:1028.35	eval-mae:1155.59
# [617]	train-mae:1028.16	eval-mae:1155.67
# [618]	train-mae:1028.06	eval-mae:1155.58
# [619]	train-mae:1027.84	eval-mae:1155.46
# [620]	train-mae:1027.73	eval-mae:1155.4
# [621]	train-mae:1027.63	eval-mae:1155.34
# [622]	train-mae:1027.51	eval-mae:1155.32
# [623]	train-mae:1027.34	eval-mae:1155.34
# [624]	train-mae:1027.25	eval-mae:1155.29
# [625]	train-mae:1027.19	eval-mae:1155.3
# [626]	train-mae:1027.01	eval-mae:1155.27
# [627]	train-mae:1026.98	eval-mae:1155.2
# [628]	train-mae:1026.88	eval-mae:1155.15
# [629]	train-mae:1026.7	eval-mae:1155.03
# [630]	train-mae:1026.6	eval-mae:1155.13
# [631]	train-mae:1026.5	eval-mae:1155.15
# [632]	train-mae:1026.38	eval-mae:1155.13
# [633]	train-mae:1026.28	eval-mae:1155.14
# [634]	train-mae:1026.15	eval-mae:1155.13
# [635]	train-mae:1025.96	eval-mae:1155.12
# [636]	train-mae:1025.84	eval-mae:1155.08
# [637]	train-mae:1025.71	eval-mae:1155.15
# [638]	train-mae:1025.59	eval-mae:1155.16
# [639]	train-mae:1025.56	eval-mae:1155.13
# [640]	train-mae:1025.41	eval-mae:1155.07
# [641]	train-mae:1025.35	eval-mae:1154.98
# [642]	train-mae:1025.24	eval-mae:1154.95
# [643]	train-mae:1025.09	eval-mae:1154.89
# [644]	train-mae:1024.99	eval-mae:1154.84
# [645]	train-mae:1024.89	eval-mae:1154.86
# [646]	train-mae:1024.68	eval-mae:1154.9
# [647]	train-mae:1024.49	eval-mae:1154.99
# [648]	train-mae:1024.34	eval-mae:1154.91
# [649]	train-mae:1024.2	eval-mae:1154.79
# [650]	train-mae:1024.07	eval-mae:1154.77
# [651]	train-mae:1023.95	eval-mae:1154.74
# [652]	train-mae:1023.87	eval-mae:1154.72
# [653]	train-mae:1023.69	eval-mae:1154.67
# [654]	train-mae:1023.57	eval-mae:1154.67
# [655]	train-mae:1023.41	eval-mae:1154.73
# [656]	train-mae:1023.33	eval-mae:1154.61
# [657]	train-mae:1023.26	eval-mae:1154.66
# [658]	train-mae:1023.11	eval-mae:1154.65
# [659]	train-mae:1022.99	eval-mae:1154.64
# [660]	train-mae:1022.93	eval-mae:1154.67
# [661]	train-mae:1022.87	eval-mae:1154.68
# [662]	train-mae:1022.75	eval-mae:1154.57
# [663]	train-mae:1022.65	eval-mae:1154.55
# [664]	train-mae:1022.44	eval-mae:1154.46
# [665]	train-mae:1022.32	eval-mae:1154.39
# [666]	train-mae:1022.24	eval-mae:1154.4
# [667]	train-mae:1022.19	eval-mae:1154.42
# [668]	train-mae:1022.15	eval-mae:1154.37
# [669]	train-mae:1022.07	eval-mae:1154.38
# [670]	train-mae:1021.85	eval-mae:1154.39
# [671]	train-mae:1021.82	eval-mae:1154.38
# [672]	train-mae:1021.58	eval-mae:1154.41
# [673]	train-mae:1021.44	eval-mae:1154.29
# [674]	train-mae:1021.25	eval-mae:1154.35
# [675]	train-mae:1021.07	eval-mae:1154.28
# [676]	train-mae:1021.01	eval-mae:1154.23
# [677]	train-mae:1020.92	eval-mae:1154.19
# [678]	train-mae:1020.81	eval-mae:1154.24
# [679]	train-mae:1020.67	eval-mae:1154.22
# [680]	train-mae:1020.6	eval-mae:1154.13
# [681]	train-mae:1020.53	eval-mae:1154.14
# [682]	train-mae:1020.45	eval-mae:1154.21
# [683]	train-mae:1020.24	eval-mae:1154.2
# [684]	train-mae:1020.05	eval-mae:1154.25
# [685]	train-mae:1019.91	eval-mae:1154.21
# [686]	train-mae:1019.83	eval-mae:1154.15
# [687]	train-mae:1019.72	eval-mae:1154.14
# [688]	train-mae:1019.67	eval-mae:1154.17
# [689]	train-mae:1019.55	eval-mae:1154.13
# [690]	train-mae:1019.44	eval-mae:1154.16
# [691]	train-mae:1019.41	eval-mae:1154.17
# [692]	train-mae:1019.31	eval-mae:1154.14
# [693]	train-mae:1019.15	eval-mae:1154.21
# [694]	train-mae:1018.97	eval-mae:1154.2
# [695]	train-mae:1018.88	eval-mae:1154.22
# [696]	train-mae:1018.76	eval-mae:1154.23
# [697]	train-mae:1018.67	eval-mae:1154.27
# [698]	train-mae:1018.58	eval-mae:1154.23
# [699]	train-mae:1018.52	eval-mae:1154.24
# [700]	train-mae:1018.44	eval-mae:1154.24
# [701]	train-mae:1018.35	eval-mae:1154.21
# [702]	train-mae:1018.22	eval-mae:1154.23
# [703]	train-mae:1018.14	eval-mae:1154.21
# [704]	train-mae:1018.08	eval-mae:1154.17
# [705]	train-mae:1017.93	eval-mae:1154.1
# [706]	train-mae:1017.88	eval-mae:1154.08
# [707]	train-mae:1017.75	eval-mae:1154.08
# [708]	train-mae:1017.64	eval-mae:1154.06
# [709]	train-mae:1017.6	eval-mae:1154.04
# [710]	train-mae:1017.52	eval-mae:1154.06
# [711]	train-mae:1017.35	eval-mae:1154.05
# [712]	train-mae:1017.32	eval-mae:1154.04
# [713]	train-mae:1017.22	eval-mae:1154.05
# [714]	train-mae:1017.04	eval-mae:1154.08
# [715]	train-mae:1016.93	eval-mae:1154.03
# [716]	train-mae:1016.85	eval-mae:1153.98
# [717]	train-mae:1016.65	eval-mae:1153.97
# [718]	train-mae:1016.52	eval-mae:1153.95
# [719]	train-mae:1016.43	eval-mae:1153.91
# [720]	train-mae:1016.29	eval-mae:1153.84
# [721]	train-mae:1016.22	eval-mae:1153.79
# [722]	train-mae:1016.04	eval-mae:1153.79
# [723]	train-mae:1015.91	eval-mae:1153.77
# [724]	train-mae:1015.75	eval-mae:1153.79
# [725]	train-mae:1015.65	eval-mae:1153.78
# [726]	train-mae:1015.58	eval-mae:1153.74
# [727]	train-mae:1015.5	eval-mae:1153.68
# [728]	train-mae:1015.36	eval-mae:1153.62
# [729]	train-mae:1015.32	eval-mae:1153.62
# [730]	train-mae:1015.23	eval-mae:1153.61
# [731]	train-mae:1015.09	eval-mae:1153.51
# [732]	train-mae:1014.98	eval-mae:1153.56
# [733]	train-mae:1014.91	eval-mae:1153.5
# [734]	train-mae:1014.84	eval-mae:1153.56
# [735]	train-mae:1014.64	eval-mae:1153.47
# [736]	train-mae:1014.57	eval-mae:1153.46
# [737]	train-mae:1014.5	eval-mae:1153.49
# [738]	train-mae:1014.46	eval-mae:1153.51
# [739]	train-mae:1014.35	eval-mae:1153.53
# [740]	train-mae:1014.24	eval-mae:1153.57

# %%
loaded_model = pickle.load(open("model_fold3score_2958.40918066best_round5.dat", "rb"))

# %%
scores_val = loaded_model.predict(d_valid, ntree_limit=clf.best_ntree_limit)
cv_score = mean_absolute_error(np.exp(y_val), np.exp(scores_val))

# %%
mpred = pred / n_folds
score = cv_sum / n_folds
print('Average eval-MAE: %.6f' % score)
n_rounds = int(np.mean(xgb_rounds))

print("Writing results")
result = pd.DataFrame(mpred, columns=['loss'])
result["id"] = ids
result = result.set_index("id")
print("%d-fold average prediction:" % n_folds)

now = datetime.now()
score = str(round((cv_sum / n_folds), 6))
sub_file = 'xgb_6_submission_5fold-average-xgb_fairobj_' + str(score) + '_' + str(
    now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
print("Writing submission: %s" % sub_file)
result.to_csv(sub_file, index=True, index_label='id')
